# %% [markdown]
# # Week 4 - NLP and Deep Learning
#
# ---
#
# # Lecture 7. RNN
#
# In assignments for this lecture we are going to implement an RNN POS tagger in Pytorch.
#
# You can use the following function for data reading:

# %%
def read_conll_file(path):
    """
    read in conll file
    
    :param path: path to read from
    :returns: list with sequences of words and labels for each sentence
    """
    data = []
    current_words = []
    current_tags = []

    for line in open(path, encoding='utf-8'):
        line = line.strip()

        if line:
            if line[0] == '#':
                continue # skip comments
            tok = line.split('\t')

            current_words.append(tok[0])
            current_tags.append(tok[1])
        else:
            if current_words:  # skip empty lines
                data.append((current_words, current_tags))
            current_words = []
            current_tags = []

    # check for last one
    if current_tags != []:
        data.append((current_words, current_tags))
    return data

train_data = read_conll_file('pos-data/en_ewt-train.conll')
dev_data = read_conll_file('pos-data/en_ewt-dev.conll')

print(len(train_data))
print(len(dev_data))
print(max([len(x[0]) for x in train_data ]))
# Out:
# 12543
# 2000
# 159

# %%
print(train_data[:20])
# Out:
# [(['Al', '-', 'Zaman', ':', 'American', 'forces', 'killed', 'Shaikh', 'Abdullah', 'al', '-', 'Ani', ',', 'the', 'preacher', 'at', 'the', 'mosque', 'in', 'the', 'town', 'of', 'Qaim', ',', 'near', 'the', 'Syrian', 'border', '.'], ['PROPN', 'PUNCT', 'PROPN', 'PUNCT', 'ADJ', 'NOUN', 'VERB', 'PROPN', 'PROPN', 'PROPN', 'PUNCT', 'PROPN', 'PUNCT', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'PROPN', 'PUNCT', 'ADP', 'DET', 'ADJ', 'NOUN', 'PUNCT']), (['[', 'This', 'killing', 'of', 'a', 'respected', 'cleric', 'will', 'be', 'causing', 'us', 'trouble', 'for', 'years', 'to', 'come', '.', ']'], ['PUNCT', 'DET', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'AUX', 'AUX', 'VERB', 'PRON', 'NOUN', 'ADP', 'NOUN', 'PART', 'VERB', 'PUNCT', 'PUNCT']), (['DPA', ':', 'Iraqi', 'authorities', 'announced', 'that', 'they', 'had', 'busted', 'up', '3', 'terrorist', 'cells', 'operating', 'in', 'Baghdad', '.'], ['PROPN', 'PUNCT', 'ADJ', 'NOUN', 'VERB', 'SCONJ', 'PRON', 'AUX', 'VERB', 'ADP', 'NUM', 'ADJ', 'NOUN', 'VERB', 'ADP', 'PROPN', 'PUNCT']), (['Two', 'of', 'them', 'were', 'being', 'run', 'by', '2', 'officials', 'of', 'the', 'Ministry', 'of', 'the', 'Interior', '!'], ['NUM', 'ADP', 'PRON', 'AUX', 'AUX', 'VERB', 'ADP', 'NUM', 'NOUN', 'ADP', 'DET', 'PROPN', 'ADP', 'DET', 'PROPN', 'PUNCT']), (['The', 'MoI', 'in', 'Iraq', 'is', 'equivalent', 'to', 'the', 'US', 'FBI', ',', 'so', 'this', 'would', 'be', 'like', 'having', 'J.', 'Edgar', 'Hoover', 'unwittingly', 'employ', 'at', 'a', 'high', 'level', 'members', 'of', 'the', 'Weathermen', 'bombers', 'back', 'in', 'the', '1960s', '.'], ['DET', 'PROPN', 'ADP', 'PROPN', 'AUX', 'ADJ', 'ADP', 'DET', 'PROPN', 'PROPN', 'PUNCT', 'ADV', 'PRON', 'AUX', 'AUX', 'SCONJ', 'VERB', 'PROPN', 'PROPN', 'PROPN', 'ADV', 'VERB', 'ADP', 'DET', 'ADJ', 'NOUN', 'NOUN', 'ADP', 'DET', 'PROPN', 'NOUN', 'ADV', 'ADP', 'DET', 'NOUN', 'PUNCT']), (['The', 'third', 'was', 'being', 'run', 'by', 'the', 'head', 'of', 'an', 'investment', 'firm', '.'], ['DET', 'ADJ', 'AUX', 'AUX', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'PUNCT']), (['You', 'wonder', 'if', 'he', 'was', 'manipulating', 'the', 'market', 'with', 'his', 'bombing', 'targets', '.'], ['PRON', 'VERB', 'SCONJ', 'PRON', 'AUX', 'VERB', 'DET', 'NOUN', 'ADP', 'PRON', 'NOUN', 'NOUN', 'PUNCT']), (['The', 'cells', 'were', 'operating', 'in', 'the', 'Ghazaliyah', 'and', 'al', '-', 'Jihad', 'districts', 'of', 'the', 'capital', '.'], ['DET', 'NOUN', 'AUX', 'VERB', 'ADP', 'DET', 'PROPN', 'CCONJ', 'PROPN', 'PUNCT', 'PROPN', 'NOUN', 'ADP', 'DET', 'NOUN', 'PUNCT']), (['Although', 'the', 'announcement', 'was', 'probably', 'made', 'to', 'show', 'progress', 'in', 'identifying', 'and', 'breaking', 'up', 'terror', 'cells', ',', 'I', 'do', "n't", 'find', 'the', 'news', 'that', 'the', 'Baathists', 'continue', 'to', 'penetrate', 'the', 'Iraqi', 'government', 'very', 'hopeful', '.'], ['SCONJ', 'DET', 'NOUN', 'AUX', 'ADV', 'VERB', 'PART', 'VERB', 'NOUN', 'SCONJ', 'VERB', 'CCONJ', 'VERB', 'ADP', 'NOUN', 'NOUN', 'PUNCT', 'PRON', 'AUX', 'PART', 'VERB', 'DET', 'NOUN', 'SCONJ', 'DET', 'PROPN', 'VERB', 'PART', 'VERB', 'DET', 'ADJ', 'NOUN', 'ADV', 'ADJ', 'PUNCT']), (['It', 'reminds', 'me', 'too', 'much', 'of', 'the', 'ARVN', 'officers', 'who', 'were', 'secretly', 'working', 'for', 'the', 'other', 'side', 'in', 'Vietnam', '.'], ['PRON', 'VERB', 'PRON', 'ADV', 'ADV', 'ADP', 'DET', 'PROPN', 'NOUN', 'PRON', 'AUX', 'ADV', 'VERB', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'PROPN', 'PUNCT']), (['Al', '-', 'Zaman', ':', 'Guerrillas', 'killed', 'a', 'member', 'of', 'the', 'Kurdistan', 'Democratic', 'Party', 'after', 'kidnapping', 'him', 'in', 'Mosul', '.'], ['PROPN', 'PUNCT', 'PROPN', 'PUNCT', 'NOUN', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'PROPN', 'ADJ', 'PROPN', 'SCONJ', 'VERB', 'PRON', 'ADP', 'PROPN', 'PUNCT']), (['The', 'police', 'commander', 'of', 'Ninevah', 'Province', 'announced', 'that', 'bombings', 'had', 'declined', '80', 'percent', 'in', 'Mosul', ',', 'whereas', 'there', 'had', 'been', 'a', 'big', 'jump ...

# %% [markdown]
# ## 1. Prepare data for use in PyTorch
#
# * a) Convert the data to a format that can be used in a Pytorch module. This means we require:
#
#   * training data: matrix of number of instances (12543) by the maximum sentence length (159), filled with word indices
#   * training labels: matrix of the same size in the first dimension, but filled with label indexes instead ( total of 17)
#   * the same two sets for the dev data (note that no word indices can be added anymore)
#
# A special `<PAD>` token can be used for padding, for sentences shorter as 159 words. For the unknown words in the test set, you can use the `<PAD>` token as well.
#
# **HINT** It will be beneficial in the long run to make a function to convert your data to the right format, as you would have to do it for the train, dev and test sets, and for any other dataset you want to evaluate on.

# %%
import torch


class Vocab():
    def __init__(self, pad_unk='<PAD>'):
        """
        A convenience class that can help store a vocabulary
        and retrieve indices for inputs.
        """
        self.pad_unk = pad_unk
        self.word2idx = {self.pad_unk: 0}
        self.idx2word = [self.pad_unk]

    def getIdx(self, word, add=False):
        if word not in self.word2idx:
            if add:
                self.word2idx[word] = len(self.idx2word)
                self.idx2word.append(word)
            else:
                return self.word2idx[self.pad_unk]
        return self.word2idx[word]

    def getWord(self, idx):
        return self.idx2word(idx)

max_len= max([len(x[0]) for x in train_data ])

# Your implementation goes here:

word_vocab = Vocab()
label_vocab = Vocab()

def convert_data(data, max_len, word_vocab, label_vocab, is_training=False):
    number_of_instances = len(data)

    word_tensor = torch.zeros((number_of_instances, max_len), dtype=torch.long)
    tag_tensor = torch.zeros((number_of_instances, max_len), dtype=torch.long)

    for i, (words, tags) in enumerate(data):
        for j, word in enumerate(words):
            word_tensor[i, j] = word_vocab.getIdx(word, add=is_training)
            tag_tensor[i, j] = label_vocab.getIdx(tags[j], add=is_training)
    
    return word_tensor, tag_tensor

train_x, train_y = convert_data(train_data, max_len, word_vocab, label_vocab, is_training=True)
dev_x, dev_y = convert_data(dev_data, max_len, word_vocab, label_vocab)

# %% [markdown]
# * b) Until now, we have used a batch-size of 1 in our implemented models, meaning that the models weights are updated after each sentence. This is not very computationally efficient. Larger batch-sizes increase the training speed, and can also lead to better performance (more stable training). You can easily convert existing training data to batches, by splitting it up in chunks of `batch_size` sentences, like this (*Make sure you understand this code!*):

# %%
import torch
# 200 instances, 100 features/weights
tmp_feats = torch.zeros((200, 100))

batch_size = 32
num_batches = int(len(tmp_feats)/batch_size)

print(num_batches)

print(tmp_feats.shape)

tmp_feats_batches = tmp_feats[:batch_size*num_batches].view(num_batches,batch_size, 100)

# 6 batches with 32 instances with 100 features
print(tmp_feats_batches.shape)

print()
for feats_batch in tmp_feats_batches:
    print(feats_batch.shape)
    # Here you can call forward/calculate the loss etc.
# Out:
# 6
# torch.Size([200, 100])
# torch.Size([6, 32, 100])
#
# torch.Size([32, 100])
# torch.Size([32, 100])
# torch.Size([32, 100])
# torch.Size([32, 100])
# torch.Size([32, 100])
# torch.Size([32, 100])

# %% [markdown]
# Note that this throws away a tiny part of the data (the last `len(tmp_feats)%batch_size`=6 samples), an alternative would be to pad, and ignore the padded part of the last batch for the loss. For the following assignments you can leave the remaining samples out (note that the dev set is dividable by 16 in this case). Furthermore, note that PyTorch supports a more advanced method for batching: [data loaders](https://pytorch.org/docs/stable/data.html), which we will not cover in this course (but you can use them for the final project).
#
# Convert your training data and labels to batches of batch size 16

# %%
# Your implementation goes here:

batch_size = 16

num_batches = len(train_x) // batch_size
train_x_batches = train_x[:batch_size*num_batches].view(num_batches,batch_size, max_len)
train_y_batches = train_y[:batch_size*num_batches].view(num_batches,batch_size, max_len)

print(train_x_batches.shape)
print(train_y_batches.shape)
# Out:
# torch.Size([783, 16, 159])
# torch.Size([783, 16, 159])

# %% [markdown]
# ## 2 Train an RNN

# %% [markdown]
# * a) Implement a POS tagger model in Pytorch using a [`torch.nn.Embedding`](https://pytorch.org/docs/stable/generated/torch.nn.Embedding.html) layer for word representations and a [`torch.nn.RNN`](https://pytorch.org/docs/stable/generated/torch.nn.RNN.html) layer. You can use a [`torch.nn.Linear`](https://pytorch.org/docs/stable/generated/torch.nn.Linear.html) layer for prediction of the label. Train this tagger on the language identification data, and evaluate its performance. Note that during each training step, you now get the predictions and loss on a whole batch directly. Use the following hyperparameters: 5 epochs over the full training data, word embeddings dimension: 100, rnn dimension of 50, learning rate of 0.01 in an [Adam optimizer](https://pytorch.org/docs/stable/optim.html) and a [CrossEntropyLoss](https://pytorch.org/docs/stable/generated/torch.nn.CrossEntropyLoss.html).
#
# Hints:
# * **Set batch_first to true!**, as explained on the [`torch.nn.RNN`](https://pytorch.org/docs/stable/generated/torch.nn.RNN.html) page. By default the RNN expects the input to be in the shape: `(seq_len, batch, rnn_dim)`, when it is set to true it should be: `(batch, seq_len, rnn_dim)`, which is usually easier to work with.
# * Training an RNN is generally much slower compared to the machine learning models we implemented before on this data, so we suggest to start with only a sub-part of the data, like 100 or 1,000 sentences. It is also ok to use only 1,000 sentences for your final model (or use the HPC to train the full model).
# * To calculate the cross entropy loss, we need the predictions to be in the first dimension. We can convert the predictions values from our model (32\*159\*18 for 1 batch) to a flatter representation (5088\*18) by using: `.view(BATCH_SIZE * max_len, -1)`. Of course, we also have to adapt the labels from 32\*159 to 5088\*1.
#
# For more information on how to implement a Pytorch module, we refer to the code used to obtain the weights in the assignment of week 3 (`week4/train_ff.py`), and the following tutorial series: https://pytorch.org/tutorials/beginner/nlp/index.html (especially the 2nd and 4th tutorials are relevant). You can use the code below as a starting point

# %%
from torch import nn
import torch
torch.manual_seed(0)
DIM_EMBEDDING = 100
RNN_HIDDEN = 50
BATCH_SIZE = 16
LEARNING_RATE = 0.01
EPOCHS = 10

class TaggerModel(torch.nn.Module):
    def __init__(self, nwords, ntags):
        super().__init__()
        self.word_embedding = nn.Embedding(nwords, DIM_EMBEDDING)
        self.rnn = nn.RNN(DIM_EMBEDDING, RNN_HIDDEN, batch_first=True)
        self.hidden_to_tag = nn.Linear(RNN_HIDDEN, ntags)
        
    def forward(self, inputData):
        word_vectors = self.word_embedding(inputData)
        rnn_out, _ = self.rnn(word_vectors)
        tag_space = self.hidden_to_tag(rnn_out)
        return tag_space
        
model = TaggerModel(len(word_vocab.idx2word), len(label_vocab.idx2word))
optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)
loss_function = torch.nn.CrossEntropyLoss(ignore_index=0, reduction='sum')


for epoch in range(EPOCHS):
    model.train()
    total_loss = 0
    # reset the gradient
    model.zero_grad()
    # loop over batches
    for x_batch, y_batch in zip(train_x_batches, train_y_batches):

        predicted_values = model.forward(x_batch)

        flat_predictions = predicted_values.view(BATCH_SIZE * max_len, -1)
        flat_targets = y_batch.view(BATCH_SIZE * max_len)

        # calculate loss (and print)
        loss = loss_function(flat_predictions, flat_targets)
        
        # update
        loss.backward()
        optimizer.step()

        total_loss += loss.item()
    
    print(f"Epoch {epoch}: Loss = {total_loss}")

def predict(model, x_data):
    model.eval()

    with torch.no_grad():
        outputs = model(x_data)
        predictions = torch.argmax(outputs, dim=-1)
    
    return predictions
# Out:
# tensor(1008.8643, grad_fn=<NllLossBackward0>)
# tensor(943.0784, grad_fn=<NllLossBackward0>)
# tensor(807.1681, grad_fn=<NllLossBackward0>)
# tensor(1419.4291, grad_fn=<NllLossBackward0>)
# tensor(998.4139, grad_fn=<NllLossBackward0>)
# tensor(451.8121, grad_fn=<NllLossBackward0>)
# tensor(50.6081, grad_fn=<NllLossBackward0>)
# tensor(525.9020, grad_fn=<NllLossBackward0>)
# tensor(836.1443, grad_fn=<NllLossBackward0>)
# tensor(718.0914, grad_fn=<NllLossBackward0>)
# tensor(601.5497, grad_fn=<NllLossBackward0>)
# tensor(760.3849, grad_fn=<NllLossBackward0>)
# tensor(660.9595, grad_fn=<NllLossBackward0>)
# tensor(593.8096, grad_fn=<NllLossBackward0>)
# tensor(591.1733, grad_fn=<NllLossBackward0>)
# tensor(625.8724, grad_fn=<NllLossBackward0>)
# tensor(856.1702, grad_fn=<NllLossBackward0>)
# tensor(854.7123, grad_fn=<NllLossBackward0>)
# tensor(657.4202, grad_fn=<NllLossBackward0>)
# tensor(916.9893, grad_fn=<NllLossBackward0>)
# tensor(651.5080, grad_fn=<NllLossBackward0>)
# tensor(397.8512, grad_fn=<NllLossBackward0>)
# tensor(440.4850, grad_fn=<NllLossBackward0>)
# tensor(544.8781, grad_fn=<NllLossBackward0>)
# tensor(790.5150, grad_fn=<NllLossBackward0>)
# tensor(559.3330, grad_fn=<NllLossBackward0>)
# tensor(654.9366, grad_fn=<NllLossBackward0>)
# tensor(851.4647, grad_fn=<NllLossBackward0>)
# tensor(539.7216, grad_fn=<NllLossBackward0>)
# tensor(453.1519, grad_fn=<NllLossBackward0>)
# tensor(483.3977, grad_fn=<NllLossBackward0>)
# tensor(745.8224, grad_fn=<NllLossBackward0>)
# tensor(600.8093, grad_fn=<NllLossBackward0>)
# tensor(322.9518, grad_fn=<NllLossBackward0>)
# tensor(621.7222, grad_fn=<NllLossBackward0>)
# tensor(775.8853, grad_fn=<NllLossBackward0>)
# tensor(800.6674, grad_fn=<NllLossBackward0>)
# tensor(625.9459, grad_fn=<NllLossBackward0>)
# tensor(612.2634, grad_fn=<NllLossBackward0>)
# tensor(640.9269, grad_fn=<NllLossBackward0>)
# tensor(719.8897, grad_fn=<NllLossBackward0>)
# tensor(797.2743, grad_fn=<NllLossBackward0>)
# tensor(791.2196, grad_fn=<NllLossBackward0>)
# tensor(722.0317, grad_fn=<NllLossBackward0>)
# tensor(329.3960, grad_fn=<NllLossBackward0>)
# tensor(558.8750, grad_fn=<NllLossBackward0>)
# tensor(578.5011, grad_fn=<NllLossBackward0>)
# tensor(497.2087, grad_fn=<NllLossBackward0>)
# tensor(493.4299, grad_fn=<NllLossBackward0>)
# tensor(494.4979, grad_fn=<NllLossBackward0>)
# tensor(408.3692, grad_fn=<NllLossBackward0>)
# tensor(604.5073, grad_fn=<NllLossBackward0>)
# tensor(570.3721, grad_fn=<NllLossBackward0>)
# tensor(576.5554, grad_fn=<NllLossBackward0>)
# tensor(477.0984, grad_fn=<NllLossBackward0>)
# tensor(452.6118, grad_fn=<NllLossBackward0>)
# tensor(506.7138, grad_fn=<NllLossBackward0>)
# tensor(622.9541, grad_fn=<NllLossBackward0>)
# tensor(426.6114, grad_fn=<NllLossBackward0>)
# tensor(474.2416, grad_fn=<NllLossBackward0>)
# tensor(420.2926, grad_fn=<NllLossBackward0>)
# tensor(523.0513, grad_fn=<NllLossBackward0>)
# tensor(459.2142, grad_fn=<NllLossBackward0>)
# tensor(539.6649, grad_fn=<NllLossBackward0>)
# tensor(402.6294, grad_fn=<NllLossBackward0>)
# tensor(415.8220, grad_fn=<NllLossBackward0>)
# tensor(600.8463, grad_fn=<NllLossBackward0>)
# tensor(482.0864, grad_fn=<NllLossBackward0>)
# tensor(729.0351, grad_fn=<NllLossBackward0>)
# tensor(558.0154, grad_fn=<NllLossBackward0>)
# tensor(800.5518, grad_fn=<NllLossBackward0>)
# tensor(723.9310, grad_fn=<NllLossBackward0>)
# tensor(461.4105, grad_fn=<NllLossBackward0>)
# tensor(499.3176, grad_fn=<NllLossBackward0>)
# tensor(475.1899, grad_fn=<NllLossBackward0>)
# tensor(646.5095, grad_fn=<NllLossBackward0>)
# tensor(646.3139, grad_fn=<NllLossBackward0>)
# tensor(699.0571, grad_fn=<NllLossBackward0>)
# tensor(944.5428, grad_fn=<NllLossBackward0>)
# tensor(568.0527, grad_fn=<NllLossBackward0>)
# tensor(727.2143, grad_fn=<NllLossBackward0>)
# tensor(590.8544, grad_fn=<NllLossBackward0>)
# tensor(475.9636, grad_fn=<NllLossBackward0>)
# tensor(676.9944, grad_fn=<NllLossBackward0>)
# tensor(618.3693, grad_fn=<NllLossBackward0>)
# tensor(1056.9216, grad_fn=<NllLossBackward0>)
# tensor(814.1282, grad_fn=<NllLossBackward0>)
# tensor(739.7940, grad_fn=<NllLossBackward0>)
# tensor(827.1646, grad_fn=<NllLossBackward0>)
# tensor(1067.9061, grad_fn=<NllLossBackward0>)
# tensor(809.8798, grad_fn=<NllLossBackward0>)
# tensor(759.9763, grad_fn=<NllLossBackward0>)
# tensor(628.1317, grad_fn=<NllLossBackward0>)
# tensor(833.9637, grad_fn=<NllLossBackward0>)
# tensor(980.3452, grad_fn=<NllLossBackward0>)
# tensor(616.4947, grad_fn=<NllLossBackward0>)
# tensor(859.9704, grad_fn=<NllLossBackward0>)
# tensor(739.0546, grad_fn=<NllLossBackward0>)
# tensor(870.5912, grad_fn=<NllLossBackward0>)
# tensor(402.2290, grad_fn=<NllLossBackward0>)
# tensor(255.1665, grad_fn=<NllLossBackward0>)
# tensor(807.5858, grad_fn=<NllLossBackward0>)
# tensor(554.8400, grad_fn=<NllLossBackward0>)
# tensor(323.3475, grad_fn=<NllLossBackward0>)
# tensor(693.2719, grad_fn=<NllLossBackward0>)
# tensor(851.1216, grad_fn=<NllLossBackward0>)
# tensor(384.2361, grad_fn=<NllLossBackward0>)
# tensor(522.9406, grad_fn=<NllLossBackward0>)
# tensor(485.4656, grad_fn=<NllLossBackward0>)
# tensor(655.1221, grad_fn=<NllLossBackward0>)
# tensor(912.1663, grad_fn=<NllLossBackward0>)
# tensor(596.3645, grad_fn=<NllLossBackward0>)
# tensor(394.4908, grad_fn=<NllLossBackward0>)
# tensor(691.4479, grad_fn=<NllLossBackward0>)
# tensor(612.7617, grad_fn=<NllLossBackward0>)
# tensor(469.2654, grad_fn=<NllLossBackward0>)
# tensor(481.3075, grad_fn=<NllLossBackward0>)
# tensor(448.6506, grad_fn=<NllLossBackward0>)
# tensor(522.0399, grad_fn=<NllLossBackward0>)
# tensor(729.1102, grad_fn=<NllLossBackward0>)
# tensor(740.9972, grad_fn=<NllLossBackward0>)
# tensor(681.7590, grad_fn=<NllLossBackward0>)
# tensor(572.8314, grad_fn=<NllLossBackward0>)
# tensor(721.9532, grad_fn=<NllLossBackward0>)
# tensor(484.4404, grad_fn=<NllLossBackward0>)
# tensor(933.4910, grad_fn=<NllLossBackward0>)
# tensor(565.1124, grad_fn=<NllLossBackward0>)
# tensor(391.9846, grad_fn=<NllLossBackward0>)
# tensor(366.8951, grad_fn=<NllLossBackward0>)
# tensor(555.5916, grad_fn=<NllLossBackward0>)
# tensor(540.8373, grad_fn=<NllLossBackward0>)
# tensor(645.3869, grad_fn=<NllLossBackward0>)
# tensor(1226.1925, grad_fn=<NllLossBackward0>)
# tensor(813.0285, grad_fn=<NllLossBackward0>)
# tensor(530.1043, grad_fn=<NllLossBackward0>)
# tensor(782.5115, grad_fn=<NllLossBackward0>)
# tensor(432.0621, grad_fn=<NllLossBackward0>)
# tensor(612.5526, grad_fn=<NllLossBackward0>)
# tensor(418.5774, grad_fn=<NllLossBackward0>)
# tensor(809.6122, grad_fn=<NllLossBackward0>)
# tensor(660.6415, grad_fn=<NllLossBackward0>)
# tensor(724.0734, grad_fn=<NllLossBackward0>)
# tensor(559.1262, grad_fn=<NllLossBackward0>)
# tensor(706.0418, grad_fn=<NllLossBackward0>)
# tensor(834.9174, grad_fn=<NllLossBackward0>)
# tensor(1604.8777, grad_fn=<NllLossBackward0>)
# tensor(876.0960, grad_fn=<NllLossBackward0>)
# tensor(685.8969, grad_fn=<NllLossBackward0>)
# tensor(779.5244, grad_fn=<NllLossBackward0>)
# tensor(328.9470, grad_fn=<NllLossBackward0>)
# tensor(461.9692, grad_fn=<NllLossBackward0>)
# tensor(449.1826, grad_fn=<NllLossBackward0>)
# tensor(563.3741, grad_fn=<NllLossBackward0>)
# tensor(1038.2499, grad_fn=<NllLossBackward0>)
# tensor(734.2999, grad_fn=<NllLossBackward0>)
# tensor(557.0148, grad_fn=<NllLossBackward0>)
# tensor(583.5785, grad_fn=<NllLossBackward0>)
# tensor(1135.3705, grad_fn=<NllLossBackward0>)
# tensor(729.5809, grad_fn=<NllLossBackward0>)
# tensor(1270.9508, grad_fn=<NllLossBackward0>)
# tensor(920.0732, grad_fn=<NllLossBackward0>)
# tensor(701.3477, grad_fn=<NllLossBackward0>)
# tensor(371.7168, grad_fn=<NllLossBackward0>)
# tensor(721.4362, grad_fn=<NllLossBackward0>)
# tensor(595.7684, grad_fn=<NllLossBackward0>)
# tensor(271.5891, grad_fn=<NllLossBackward0>)
# tensor(802.0042, grad_fn=<NllLossBackward0>)
# tensor(778.7997, grad_fn=<NllLossBackward0>)
# tensor(582.1344, grad_fn=<NllLossBackward0>)
# tensor(637.9774, grad_fn=<NllLossBackward0>)
# tensor(801.5604, grad_fn=<NllLossBackward0>)
# tensor(688.2563, grad_fn=<NllLossBackward0>)
# tensor(555.5728, grad_fn=<NllLossBackward0>)
# tensor(611.3057, grad_fn=<NllLossBackward0>)
# tensor(642.6512, grad_fn=<NllLossBackward0>)
# tensor(598.9283, grad_fn=<NllLossBackward0>)
# tensor(706.8912, grad_fn=<NllLossBackward0>)
# tensor(389.1996, grad_fn=<NllLossBackward0>)
# tensor(261.0821, grad_fn=<NllLossBackward0>)
# tensor(583.1000, grad_fn=<NllLossBackward0>)
# tensor(317.8013, grad_fn=<NllLossBackward0>)
# tensor(613.2702, grad_fn=<NllLossBackward0>)
# tensor(731.8478, grad_fn=<NllLossBackward0>)
# tensor(341.3118, grad_fn=<NllLossBackward0>)
# tensor(482.9568, grad_fn=<NllLossBackward0>)
# tensor(366.7639, grad_fn=<NllLossBackward0>)
# tensor(838.6862, grad_fn=<NllLossBackward0>)
# tensor(1080.2588, grad_fn=<NllLossBackward0>)
# tensor(750.1097, grad_fn=<NllLossBackward0>)
# tensor(1365.0157, grad_fn=<NllLossBackward0>)
# tensor(455.3512, grad_fn=<NllLossBackward0>)
# tensor(972.0894, grad_fn=<NllLossBackward0>)
# tensor(1248.7220, grad_fn=<NllLossBackward0>)
# tensor(742.8072, grad_fn=<NllLossBackward0>)
# tensor(1140.6027, grad_fn=<NllLossBackward0>)
# tensor(593.7159, grad_fn=<NllLossBackward0>)
# tensor(1296.6338, grad_fn=<NllLossBackward0>)
# tensor(863.3741, grad_fn=<NllLossBackward0>)
# tensor(775.2326, grad_fn=<NllLossBackward0>)
# tensor(1075.5463, grad_fn=<NllLossBackward0>)
# tensor(672.2238, grad_fn=<NllLossBackward0>)
# tensor(705.4744, grad_fn=<NllLossBackward0>)
# tensor(1159.6653, grad_fn=<NllLossBackward0>)
# tensor(723.8509, grad_fn=<NllLossBackward0>)
# tensor(636.4169, grad_fn=<NllLossBackward0>)
# tensor(887.1507, grad_fn=<NllLossBackward0>)
# tensor(792.5633, grad_fn=<NllLossBackward0>)
# tensor(1027.4240, grad_fn=<NllLossBackward0>)
# tensor(728.8685, grad_fn=<NllLossBackward0>)
# tensor(1418.8380, grad_fn=<NllLossBackward0>)
# tensor(1083.1262, grad_fn=<NllLossBackward0>)
# tensor(855.3301, grad_fn=<NllLossBackward0>)
# tensor(1345.2570, grad_fn=<NllLossBackward0>)
# tensor(1169.7583, grad_fn=<NllLossBackward0>)
# tensor(1074.0996, grad_fn=<NllLossBackward0>)
# tensor(1110.9835, grad_fn=<NllLossBackward0>)
# tensor(1045.8279, grad_fn=<NllLossBackward0>)
# tensor(864.8344, grad_fn=<NllLossBackward0>)
# tensor(693.7991, grad_fn=<NllLossBackward0>)
# tensor(1668.2844, grad_fn=<NllLossBackward0>)
# tensor(808.8608, grad_fn=<NllLossBackward0>)
# tensor(1452.2886, grad_fn=<NllLossBackward0>)
# tensor(878.2056, grad_fn=<NllLossBackward0>)
# tensor(426.6837, grad_fn=<NllLossBackward0>)
# tensor(1294.0128, grad_fn=<NllLossBackward0>)
# tensor(1011.7151, grad_fn=<NllLossBackward0>)
# tensor(1068.0225, grad_fn=<NllLossBackward0>)
# tensor(897.9196, grad_fn=<NllLossBackward0>)
# tensor(543.9235, grad_fn=<NllLossBackward0>)
# tensor(1185.7041, grad_fn=<NllLossBackward0>)
# tensor(2187.5481, grad_fn=<NllLossBackward0>)
# tensor(1489.7394, grad_fn=<NllLossBackward0>)
# tensor(1734.5378, grad_fn=<NllLossBackward0>)
# tensor(1530.8419, grad_fn=<NllLossBackward0>)
# tensor(1297.2034, grad_fn=<NllLossBackward0>)
# tensor(1463.9596, grad_fn=<NllLossBackward0>)
# tensor(1113.4912, grad_fn=<NllLossBackward0>)
# tensor(1884.8630, grad_fn=<NllLossBackward0>)
# tensor(1461.3031, grad_fn=<NllLossBackward0>)
# tensor(1371.4409, grad_fn=<NllLossBackward0>)
# tensor(430.6718, grad_fn=<NllLossBackward0>)
# tensor(611.7683, grad_fn=<NllLossBackward0>)
# tensor(787.8636, grad_fn=<NllLossBackward0>)
# tensor(1481.7980, grad_fn=<NllLossBackward0>)
# tensor(1300.8961, grad_fn=<NllLossBackward0>)
# tensor(710.2900, grad_fn=<NllLossBackward0>)
# tensor(704.9861, grad_fn=<NllLossBackward0>)
# tensor(1361.2001, grad_fn=<NllLossBackward0>)
# tensor(1294.0842, grad_fn=<NllLossBackward0>)
# tensor(851.8831, grad_fn=<NllLossBackward0>)
# tensor(1052.5530, grad_fn=<NllLossBackward0>)
# tensor(679.1573, grad_fn=<NllLossBackward0>)
# tensor(596.0231, grad_fn=<NllLossBackward0>)
# tensor(654.7587, grad_fn=<NllLossBackward0>)
# tensor(1094.5217, grad_fn=<NllLossBackward0>)
# tensor(1010.0880, grad_fn=<NllLossBackward0>)
# tensor(659.6374, grad_fn=<NllLossBackward0>)
# tensor(668.5910, grad_fn=<NllLossBackward0>)
# tensor(827.5500, grad_fn=<NllLossBackward0>)
# tensor(552.1504, grad_fn=<NllLossBackward0>)
# tensor(1103.2722, grad_fn=<NllLossBackward0>)
# tensor(809.7942, grad_fn=<NllLossBackward0>)
# tensor(1174.4218, grad_fn=<NllLossBackward0>)
# tensor(906.6136, grad_fn=<NllLossBackward0>)
# tensor(741.7948, grad_fn=<NllLossBackward0>)
# tensor(237.3383, grad_fn=<NllLossBackward0>)
# tensor(681.3420, grad_fn=<NllLossBackward0>)
# tensor(526.6957, grad_fn=<NllLossBackward0>)
# tensor(609.2698, grad_fn=<NllLossBackward0>)
# tensor(785.8700, grad_fn=<NllLossBackward0>)
# tensor(469.7367, grad_fn=<NllLossBackward0>)
# tensor(549.8942, grad_fn=<NllLossBackward0>)
# tensor(439.7459, grad_fn=<NllLossBackward0>)
# tensor(645.0552, grad_fn=<NllLossBackward0>)
# tensor(695.1793, grad_fn=<NllLossBackward0>)
# tensor(712.8692, grad_fn=<NllLossBackward0>)
# tensor(770.0350, grad_fn=<NllLossBackward0>)
# tensor(539.9420, grad_fn=<NllLossBackward0>)
# tensor(375.6058, grad_fn=<NllLossBackward0>)
# tensor(604.7737, grad_fn=<NllLossBackward0>)
# tensor(768.6677, grad_fn=<NllLossBackward0>)
# tensor(1036.4062, grad_fn=<NllLossBackward0>)
# tensor(787.5378, grad_fn=<NllLossBackward0>)
# tensor(877.4164, grad_fn=<NllLossBackward0>)
# tensor(693.0330, grad_fn=<NllLossBackward0>)
# tensor(967.5346, grad_fn=<NllLossBackward0>)
# tensor(2064.5437, grad_fn=<NllLossBackward0>)
# tensor(1582.5675, grad_fn=<NllLossBackward0>)
# tensor(883.7387, grad_fn=<NllLossBackward0>)
# tensor(1037.1564, grad_fn=<NllLossBackward0>)
# tensor(1755.7043, grad_fn=<NllLossBackward0>)
# tensor(1106.2325, grad_fn=<NllLossBackward0>)
# tensor(728.9301, grad_fn=<NllLossBackward0>)
# tensor(1722.4333, grad_fn=<NllLossBackward0>)
# tensor(1445.8783, grad_fn=<NllLossBackward0>)
# tensor(914.6819, grad_fn=<NllLossBackward0>)
# tensor(693.5372, grad_fn=<NllLossBackward0>)
# tensor(868.6767, grad_fn=<NllLossBackward0>)
# tensor(701.1680, grad_fn=<NllLossBackward0>)
# tensor(923.6592, grad_fn=<NllLossBackward0>)
# tensor(1296.5699, grad_fn=<NllLossBackward0>)
# tensor(1245.9200, grad_fn=<NllLossBackward0>)
# tensor(2043.2811, grad_fn=<NllLossBackward0>)
# tensor(671.8121, grad_fn=<NllLossBackward0>)
# tensor(775.6630, grad_fn=<NllLossBackward0>)
# tensor(1243.4708, grad_fn=<NllLossBackward0>)
# tensor(569.0994, grad_fn=<NllLossBackward0>)
# tensor(408.2362, grad_fn=<NllLossBackward0>)
# tensor(689.1578, grad_fn=<NllLossBackward0>)
# tensor(1484.5696, grad_fn=<NllLossBackward0>)
# tensor(711.2253, grad_fn=<NllLossBackward0>)
# tensor(978.2641, grad_fn=<NllLossBackward0>)
# tensor(1122.3521, grad_fn=<NllLossBackward0>)
# tensor(618.1155, grad_fn=<NllLossBackward0>)
# tensor(1084.0811, grad_fn=<NllLossBackward0>)
# tensor(786.5297, grad_fn=<NllLossBackward0>)
# tensor(1037.1046, grad_fn=<NllLossBackward0>)
# tensor(1269.8682, grad_fn=<NllLossBackward0>)
# tensor(840.5858, grad_fn=<NllLossBackward0>)
# tensor(1859.9556, grad_fn=<NllLossBackward0>)
# tensor(1918.4120, grad_fn=<NllLossBackward0>)
# tensor(1610.0723, grad_fn=<NllLossBackward0>)
# tensor(1325.0194, grad_fn=<NllLossBackward0>)
# tensor(894.9937, grad_fn=<NllLossBackward0>)
# tensor(1170.7610, grad_fn=<NllLossBackward0>)
# tensor(999.0381, grad_fn=<NllLossBackward0>)
# tensor(947.3115, grad_fn=<NllLossBackward0>)
# tensor(683.7659, grad_fn=<NllLossBackward0>)
# tensor(536.0883, grad_fn=<NllLossBackward0>)
# tensor(709.0779, grad_fn=<NllLossBackward0>)
# tensor(785.1144, grad_fn=<NllLossBackward0>)
# tensor(712.8746, grad_fn=<NllLossBackward0>)
# tensor(1395.0513, grad_fn=<NllLossBackward0>)
# tensor(625.9393, grad_fn=<NllLossBackward0>)
# tensor(1309.9187, grad_fn=<NllLossBackward0>)
# tensor(1580.5120, grad_fn=<NllLossBackward0>)
# tensor(1879.9564, grad_fn=<NllLossBackward0>)
# tensor(1683.4263, grad_fn=<NllLossBackward0>)
# tensor(1451.9579, grad_fn=<NllLossBackward0>)
# tensor(895.6116, grad_fn=<NllLossBackward0>)
# tensor(1192.7979, grad_fn=<NllLossBackward0>)
# tensor(1247.8088, grad_fn=<NllLossBackward0>)
# tensor(867.9006, grad_fn=<NllLossBackward0>)
# tensor(757.2956, grad_fn=<NllLossBackward0>)
# tensor(533.7496, grad_fn=<NllLossBackward0>)
# tensor(1098.8696, grad_fn=<NllLossBackward0>)
# tensor(1778.5334, grad_fn=<NllLossBackward0>)
# tensor(1440.9130, grad_fn=<NllLossBackward0>)
# tensor(1114.8689, grad_fn=<NllLossBackward0>)
# tensor(879.5352, grad_fn=<NllLossBackward0>)
# tensor(1187.7992, grad_fn=<NllLossBackward0>)
# tensor(1160.1659, grad_fn=<NllLossBackward0>)
# tensor(1243.3462, grad_fn=<NllLossBackward0>)
# tensor(1445.5854, grad_fn=<NllLossBackward0>)
# tensor(761.2588, grad_fn=<NllLossBackward0>)
# tensor(1793.0696, grad_fn=<NllLossBackward0>)
# tensor(1109.4026, grad_fn=<NllLossBackward0>)
# tensor(1463.8365, grad_fn=<NllLossBackward0>)
# tensor(3067.3770, grad_fn=<NllLossBackward0>)
# tensor(1223.4590, grad_fn=<NllLossBackward0>)
# tensor(1463.2655, grad_fn=<NllLossBackward0>)
# tensor(1517.6382, grad_fn=<NllLossBackward0>)
# tensor(1051.5896, grad_fn=<NllLossBackward0>)
# tensor(1111.0946, grad_fn=<NllLossBackward0>)
# tensor(1257.3564, grad_fn=<NllLossBackward0>)
# tensor(1596.4753, grad_fn=<NllLossBackward0>)
# tensor(1512.7488, grad_fn=<NllLossBackward0>)
# tensor(1210.4481, grad_fn=<NllLossBackward0>)
# tensor(1269.2190, grad_fn=<NllLossBackward0>)
# tensor(1251.3928, grad_fn=<NllLossBackward0>)
# tensor(2816.2969, grad_fn=<NllLossBackward0>)
# tensor(2370.9519, grad_fn=<NllLossBackward0>)
# tensor(1403.2866, grad_fn=<NllLossBackward0>)
# tensor(1519.1678, grad_fn=<NllLossBackward0>)
# tensor(1281.8354, grad_fn=<NllLossBackward0>)
# tensor(1806.9943, grad_fn=<NllLossBackward0>)
# tensor(2428.2698, grad_fn=<NllLossBackward0>)
# tensor(2251.0010, grad_fn=<NllLossBackward0>)
# tensor(2362.4609, grad_fn=<NllLossBackward0>)
# tensor(1576.5886, grad_fn=<NllLossBackward0>)
# tensor(3237.1328, grad_fn=<NllLossBackward0>)
# tensor(1673.8940, grad_fn=<NllLossBackward0>)
# tensor(2034.3302, grad_fn=<NllLossBackward0>)
# tensor(1695.4648, grad_fn=<NllLossBackward0>)
# tensor(1823.5115, grad_fn=<NllLossBackward0>)
# tensor(2532.8389, grad_fn=<NllLossBackward0>)
# tensor(1434.8182, grad_fn=<NllLossBackward0>)
# tensor(2297.8401, grad_fn=<NllLossBackward0>)
# tensor(1211.1147, grad_fn=<NllLossBackward0>)
# tensor(1421.3510, grad_fn=<NllLossBackward0>)
# tensor(1199.9801, grad_fn=<NllLossBackward0>)
# tensor(1818.9417, grad_fn=<NllLossBackward0>)
# tensor(1495.3569, grad_fn=<NllLossBackward0>)
# tensor(1631.0126, grad_fn=<NllLossBackward0>)
# tensor(1397.4365, grad_fn=<NllLossBackward0>)
# tensor(2348.9451, grad_fn=<NllLossBackward0>)
# tensor(1569.2336, grad_fn=<NllLossBackward0>)
# tensor(1780.7717, grad_fn=<NllLossBackward0>)
# tensor(1358.0442, grad_fn=<NllLossBackward0>)
# tensor(2662.3945, grad_fn=<NllLossBackward0>)
# tensor(2035.3319, grad_fn=<NllLossBackward0>)
# tensor(2951.1172, grad_fn=<NllLossBackward0>)
# tensor(1775.8713, grad_fn=<NllLossBackward0>)
# tensor(1354.9781, grad_fn=<NllLossBackward0>)
# tensor(1466.9139, grad_fn=<NllLossBackward0>)
# tensor(2025.2423, grad_fn=<NllLossBackward0>)
# tensor(1772.9200, grad_fn=<NllLossBackward0>)
# tensor(1522.5179, grad_fn=<NllLossBackward0>)
# tensor(1882.1139, grad_fn=<NllLossBackward0>)
# tensor(1694.2396, grad_fn=<NllLossBackward0>)
# tensor(1521.2250, grad_fn=<NllLossBackward0>)
# tensor(1374.9814, grad_fn=<NllLossBackward0>)
# tensor(1234.9769, grad_fn=<NllLossBackward0>)
# tensor(1715.4922, grad_fn=<NllLossBackward0>)
# tensor(1498.0887, grad_fn=<NllLossBackward0>)
# tensor(1317.3810, grad_fn=<NllLossBackward0>)
# tensor(1973.4452, grad_fn=<NllLossBackward0>)
# tensor(2809.7295, grad_fn=<NllLossBackward0>)
# tensor(1939.8309, grad_fn=<NllLossBackward0>)
# tensor(1242.3562, grad_fn=<NllLossBackward0>)
# tensor(3275.9299, grad_fn=<NllLossBackward0>)
# tensor(1825.9414, grad_fn=<NllLossBackward0>)
# tensor(2414.4209, grad_fn=<NllLossBackward0>)
# tensor(3979.7271, grad_fn=<NllLossBackward0>)
# tensor(3426.3252, grad_fn=<NllLossBackward0>)
# tensor(2591.4465, grad_fn=<NllLossBackward0>)
# tensor(2192.3164, grad_fn=<NllLossBackward0>)
# tensor(2163.4983, grad_fn=<NllLossBackward0>)
# tensor(2344.0154, grad_fn=<NllLossBackward0>)
# tensor(1908.5237, grad_fn=<NllLossBackward0>)
# tensor(2296.6494, grad_fn=<NllLossBackward0>)
# tensor(2564.2454, grad_fn=<NllLossBackward0>)
# tensor(1661.9443, grad_fn=<NllLossBackward0>)
# tensor(2525.0903, grad_fn=<NllLossBackward0>)
# tensor(1683.0344, grad_fn=<NllLossBackward0>)
# tensor(2601.0474, grad_fn=<NllLossBackward0>)
# tensor(1880.0005, grad_fn=<NllLossBackward0>)
# tensor(2654.9839, grad_fn=<NllLossBackward0>)
# tensor(2306.5159, grad_fn=<NllLossBackward0>)
# tensor(1940.8054, grad_fn=<NllLossBackward0>)
# tensor(2272.1157, grad_fn=<NllLossBackward0>)
# tensor(1865.2053, grad_fn=<NllLossBackward0>)
# tensor(1953.3041, grad_fn=<NllLossBackward0>)
# tensor(1886.4955, grad_fn=<NllLossBackward0>)
# tensor(1493.0275, grad_fn=<NllLossBackward0>)
# tensor(1586.2566, grad_fn=<NllLossBackward0>)
# tensor(1506.1835, grad_fn=<NllLossBackward0>)
# tensor(2229.5703, grad_fn=<NllLossBackward0>)
# tensor(1589.2156, grad_fn=<NllLossBackward0>)
# tensor(1560.4066, grad_fn=<NllLossBackward0>)
# tensor(1573.8533, grad_fn=<NllLossBackward0>)
# tensor(1133.4397, grad_fn=<NllLossBackward0>)
# tensor(1309.8773, grad_fn=<NllLossBackward0>)
# tensor(1998.9219, grad_fn=<NllLossBackward0>)
# tensor(1325.0128, grad_fn=<NllLossBackward0>)
# tensor(1069.6823, grad_fn=<NllLossBackward0>)
# tensor(1727.9305, grad_fn=<NllLossBackward0>)
# tensor(1137.8212, grad_fn=<NllLossBackward0>)
# tensor(920.5184, grad_fn=<NllLossBackward0>)
# tensor(1363.8441, grad_fn=<NllLossBackward0>)
# tensor(1017.9736, grad_fn=<NllLossBackward0>)
# tensor(1280.2329, grad_fn=<NllLossBackward0>)
# tensor(1545.9879, grad_fn=<NllLossBackward0>)
# tensor(1276.2283, grad_fn=<NllLossBackward0>)
# tensor(1215.5336, grad_fn=<NllLossBackward0>)
# tensor(1510.6515, grad_fn=<NllLossBackward0>)
# tensor(1349.2018, grad_fn=<NllLossBackward0>)
# tensor(1877.4779, grad_fn=<NllLossBackward0>)
# tensor(1236.8822, grad_fn=<NllLossBackward0>)
# tensor(2443.8787, grad_fn=<NllLossBackward0>)
# tensor(1493.5330, grad_fn=<NllLossBackward0>)
# tensor(916.8362, grad_fn=<NllLossBackward0>)
# tensor(1089.6145, grad_fn=<NllLossBackward0>)
# tensor(1822.9938, grad_fn=<NllLossBackward0>)
# tensor(989.0488, grad_fn=<NllLossBackward0>)
# tensor(1563.7700, grad_fn=<NllLossBackward0>)
# tensor(1088.9089, grad_fn=<NllLossBackward0>)
# tensor(1136.1843, grad_fn=<NllLossBackward0>)
# tensor(1130.4449, grad_fn=<NllLossBackward0>)
# tensor(1205.9192, grad_fn=<NllLossBackward0>)
# tensor(1177.2190, grad_fn=<NllLossBackward0>)
# tensor(1200.7589, grad_fn=<NllLossBackward0>)
# tensor(1372.9852, grad_fn=<NllLossBackward0>)
# tensor(1074.7255, grad_fn=<NllLossBackward0>)
# tensor(1227.0111, grad_fn=<NllLossBackward0>)
# tensor(979.3738, grad_fn=<NllLossBackward0>)
# tensor(1106.0427, grad_fn=<NllLossBackward0>)
# tensor(1298.4917, grad_fn=<NllLossBackward0>)
# tensor(1638.6707, grad_fn=<NllLossBackward0>)
# tensor(1318.7557, grad_fn=<NllLossBackward0>)
# tensor(1026.3884, grad_fn=<NllLossBackward0>)
# tensor(1374.8723, grad_fn=<NllLossBackward0>)
# tensor(1342.9636, grad_fn=<NllLossBackward0>)
# tensor(1388.3738, grad_fn=<NllLossBackward0>)
# tensor(1159.6729, grad_fn=<NllLossBackward0>)
# tensor(1537.4767, grad_fn=<NllLossBackward0>)
# tensor(1855.5085, grad_fn=<NllLossBackward0>)
# tensor(1993.3062, grad_fn=<NllLossBackward0>)
# tensor(1216.4032, grad_fn=<NllLossBackward0>)
# tensor(1783.2078, grad_fn=<NllLossBackward0>)
# tensor(1449.1052, grad_fn=<NllLossBackward0>)
# tensor(1464.5769, grad_fn=<NllLossBackward0>)
# tensor(1361.7225, grad_fn=<NllLossBackward0>)
# tensor(2511.8225, grad_fn=<NllLossBackward0>)
# tensor(1763.0104, grad_fn=<NllLossBackward0>)
# tensor(750.4213, grad_fn=<NllLossBackward0>)
# tensor(1647.0518, grad_fn=<NllLossBackward0>)
# tensor(1304.0906, grad_fn=<NllLossBackward0>)
# tensor(1120.4274, grad_fn=<NllLossBackward0>)
# tensor(2049.3042, grad_fn=<NllLossBackward0>)
# tensor(1469.2805, grad_fn=<NllLossBackward0>)
# tensor(2092.5708, grad_fn=<NllLossBackward0>)
# tensor(2304.4150, grad_fn=<NllLossBackward0>)
# tensor(2658.8467, grad_fn=<NllLossBackward0>)
# tensor(1340.7208, grad_fn=<NllLossBackward0>)
# tensor(2016.3749, grad_fn=<NllLossBackward0>)
# tensor(1623.3390, grad_fn=<NllLossBackward0>)
# tensor(2226.6423, grad_fn=<NllLossBackward0>)
# tensor(1399.6149, grad_fn=<NllLossBackward0>)
# tensor(1989.8691, grad_fn=<NllLossBackward0>)
# tensor(1683.4723, grad_fn=<NllLossBackward0>)
# tensor(2112.0674, grad_fn=<NllLossBackward0>)
# tensor(2097.0676, grad_fn=<NllLossBackward0>)
# tensor(2434.2468, grad_fn=<NllLossBackward0>)
# tensor(1724.3529, grad_fn=<NllLossBackward0>)
# tensor(1506.9607, grad_fn=<NllLossBackward0>)
# tensor(1926.4426, grad_fn=<NllLossBackward0>)
# tensor(2337.4878, grad_fn=<NllLossBackward0>)
# tensor(2645.0132, grad_fn=<NllLossBackward0>)
# tensor(2320.2798, grad_fn=<NllLossBackward0>)
# tensor(2526.6516, grad_fn=<NllLossBackward0>)
# tensor(1787.4950, grad_fn=<NllLossBackward0>)
# tensor(2767.2805, grad_fn=<NllLossBackward0>)
# tensor(2377.1794, grad_fn=<NllLossBackward0>)
# tensor(2691.6770, grad_fn=<NllLossBackward0>)
# tensor(2479.2212, grad_fn=<NllLossBackward0>)
# tensor(1978.6893, grad_fn=<NllLossBackward0>)
# tensor(2522.9382, grad_fn=<NllLossBackward0>)
# tensor(1572.1760, grad_fn=<NllLossBackward0>)
# tensor(1386.7538, grad_fn=<NllLossBackward0>)
# tensor(2373.1853, grad_fn=<NllLossBackward0>)
# tensor(1688.7927, grad_fn=<NllLossBackward0>)
# tensor(2360.6846, grad_fn=<NllLossBackward0>)
# tensor(1101.5857, grad_fn=<NllLossBackward0>)
# tensor(1553.8763, grad_fn=<NllLossBackward0>)
# tensor(2187.2825, grad_fn=<NllLossBackward0>)
# tensor(1290.9741, grad_fn=<NllLossBackward0>)
# tensor(1070.8485, grad_fn=<NllLossBackward0>)
# tensor(1598.3713, grad_fn=<NllLossBackward0>)
# tensor(2039.7098, grad_fn=<NllLossBackward0>)
# tensor(1438.8182, grad_fn=<NllLossBackward0>)
# tensor(1683.4949, grad_fn=<NllLossBackward0>)
# tensor(1789.2578, grad_fn=<NllLossBackward0>)
# tensor(1720.4897, grad_fn=<NllLossBackward0>)
# tensor(2219.2681, grad_fn=<NllLossBackward0>)
# tensor(1178.1943, grad_fn=<NllLossBackward0>)
# tensor(1217.5001, grad_fn=<NllLossBackward0>)
# tensor(1502.7732, grad_fn=<NllLossBackward0>)
# tensor(1023.5438, grad_fn=<NllLossBackward0>)
# tensor(1778.4109, grad_fn=<NllLossBackward0>)
# tensor(1241.1511, grad_fn=<NllLossBackward0>)
# tensor(1400.8357, grad_fn=<NllLossBackward0>)
# tensor(1111.5682, grad_fn=<NllLossBackward0>)
# tensor(1250.2504, grad_fn=<NllLossBackward0>)
# tensor(1610.9458, grad_fn=<NllLossBackward0>)
# tensor(2120.0691, grad_fn=<NllLossBackward0>)
# tensor(2558.1235, grad_fn=<NllLossBackward0>)
# tensor(1483.6385, grad_fn=<NllLossBackward0>)
# tensor(1893.1965, grad_fn=<NllLossBackward0>)
# tensor(1427.9042, grad_fn=<NllLossBackward0>)
# tensor(2030.9022, grad_fn=<NllLossBackward0>)
# tensor(2125.5344, grad_fn=<NllLossBackward0>)
# tensor(1450.8424, grad_fn=<NllLossBackward0>)
# tensor(1040.9117, grad_fn=<NllLossBackward0>)
# tensor(2007.4885, grad_fn=<NllLossBackward0>)
# tensor(1619.5967, grad_fn=<NllLossBackward0>)
# tensor(1807.5525, grad_fn=<NllLossBackward0>)
# tensor(1221.1978, grad_fn=<NllLossBackward0>)
# tensor(1240.0786, grad_fn=<NllLossBackward0>)
# tensor(2310.6328, grad_fn=<NllLossBackward0>)
# tensor(1451.5320, grad_fn=<NllLossBackward0>)
# tensor(1739.4823, grad_fn=<NllLossBackward0>)
# tensor(2113.9446, grad_fn=<NllLossBackward0>)
# tensor(2280.2554, grad_fn=<NllLossBackward0>)
# tensor(1926.7426, grad_fn=<NllLossBackward0>)
# tensor(3186.2432, grad_fn=<NllLossBackward0>)
# tensor(3017.0945, grad_fn=<NllLossBackward0>)
# tensor(1174.1594, grad_fn=<NllLossBackward0>)
# tensor(1798.4032, grad_fn=<NllLossBackward0>)
# tensor(1493.7659, grad_fn=<NllLossBackward0>)
# tensor(2293.3230, grad_fn=<NllLossBackward0>)
# tensor(1632.6770, grad_fn=<NllLossBackward0>)
# tensor(2758.5564, grad_fn=<NllLossBackward0>)
# tensor(3318.9072, grad_fn=<NllLossBackward0>)
# tensor(1574.0142, grad_fn=<NllLossBackward0>)
# tensor(2460.3740, grad_fn=<NllLossBackward0>)
# tensor(1954.5952, grad_fn=<NllLossBackward0>)
# tensor(3193.1362, grad_fn=<NllLossBackward0>)
# tensor(1086.7582, grad_fn=<NllLossBackward0>)
# tensor(1704.0123, grad_fn=<NllLossBackward0>)
# tensor(2217.5442, grad_fn=<NllLossBackward0>)
# tensor(2573.1169, grad_fn=<NllLossBackward0>)
# tensor(1832.0123, grad_fn=<NllLossBackward0>)
# tensor(2818.1055, grad_fn=<NllLossBackward0>)
# tensor(2361.2151, grad_fn=<NllLossBackward0>)
# tensor(1598.4119, grad_fn=<NllLossBackward0>)
# tensor(4417.2852, grad_fn=<NllLossBackward0>)
# tensor(2384.6267, grad_fn=<NllLossBackward0>)
# tensor(1901.8340, grad_fn=<NllLossBackward0>)
# tensor(2024.6125, grad_fn=<NllLossBackward0>)
# tensor(1321.6765, grad_fn=<NllLossBackward0>)
# tensor(2296.6641, grad_fn=<NllLossBackward0>)
# tensor(2221.4451, grad_fn=<NllLossBackward0>)
# tensor(1686.8818, grad_fn=<NllLossBackward0>)
# tensor(972.5160, grad_fn=<NllLossBackward0>)
# tensor(1481.2240, grad_fn=<NllLossBackward0>)
# tensor(1527.1396, grad_fn=<NllLossBackward0>)
# tensor(1388.1603, grad_fn=<NllLossBackward0>)
# tensor(1526.5016, grad_fn=<NllLossBackward0>)
# tensor(1111.5177, grad_fn=<NllLossBackward0>)
# tensor(1915.8215, grad_fn=<NllLossBackward0>)
# tensor(1350.5771, grad_fn=<NllLossBackward0>)
# tensor(1709.6538, grad_fn=<NllLossBackward0>)
# tensor(1813.7396, grad_fn=<NllLossBackward0>)
# tensor(1888.2319, grad_fn=<NllLossBackward0>)
# tensor(1465.5400, grad_fn=<NllLossBackward0>)
# tensor(1988.5876, grad_fn=<NllLossBackward0>)
# tensor(1546.8124, grad_fn=<NllLossBackward0>)
# tensor(1017.6769, grad_fn=<NllLossBackward0>)
# tensor(1798.8448, grad_fn=<NllLossBackward0>)
# tensor(1484.2181, grad_fn=<NllLossBackward0>)
# tensor(1628.1694, grad_fn=<NllLossBackward0>)
# tensor(1475.1525, grad_fn=<NllLossBackward0>)
# tensor(1003.4343, grad_fn=<NllLossBackward0>)
# tensor(1662.0226, grad_fn=<NllLossBackward0>)
# tensor(1146.0649, grad_fn=<NllLossBackward0>)
# tensor(1439.6156, grad_fn=<NllLossBackward0>)
# tensor(1688.8704, grad_fn=<NllLossBackward0>)
# tensor(1654.6583, grad_fn=<NllLossBackward0>)
# tensor(1910.3683, grad_fn=<NllLossBackward0>)
# tensor(1243.6818, grad_fn=<NllLossBackward0>)
# tensor(1838.8109, grad_fn=<NllLossBackward0>)
# tensor(2104.1509, grad_fn=<NllLossBackward0>)
# tensor(2151.8733, grad_fn=<NllLossBackward0>)
# tensor(1484.1279, grad_fn=<NllLossBackward0>)
# tensor(877.9545, grad_fn=<NllLossBackward0>)
# tensor(1711.8953, grad_fn=<NllLossBackward0>)
# tensor(1249.5189, grad_fn=<NllLossBackward0>)
# tensor(1355.2928, grad_fn=<NllLossBackward0>)
# tensor(2370.6956, grad_fn=<NllLossBackward0>)
# tensor(1638.7933, grad_fn=<NllLossBackward0>)
# tensor(1963.5438, grad_fn=<NllLossBackward0>)
# tensor(2309.7102, grad_fn=<NllLossBackward0>)
# tensor(1578.6680, grad_fn=<NllLossBackward0>)
# tensor(2174.1150, grad_fn=<NllLossBackward0>)
# tensor(1145.7072, grad_fn=<NllLossBackward0>)
# tensor(1849.7452, grad_fn=<NllLossBackward0>)
# tensor(1258.8391, grad_fn=<NllLossBackward0>)
# tensor(2127.5791, grad_fn=<NllLossBackward0>)
# tensor(2277.7949, grad_fn=<NllLossBackward0>)
# tensor(1538.1425, grad_fn=<NllLossBackward0>)
# tensor(1490.9048, grad_fn=<NllLossBackward0>)
# tensor(1787.1683, grad_fn=<NllLossBackward0>)
# tensor(1888.6725, grad_fn=<NllLossBackward0>)
# tensor(2324.7686, grad_fn=<NllLossBackward0>)
# tensor(1829.0940, grad_fn=<NllLossBackward0>)
# tensor(1504.8113, grad_fn=<NllLossBackward0>)
# tensor(3597.0781, grad_fn=<NllLossBackward0>)
# tensor(1674.6622, grad_fn=<NllLossBackward0>)
# tensor(1418.7206, grad_fn=<NllLossBackward0>)
# tensor(2072.3572, grad_fn=<NllLossBackward0>)
# tensor(1324.6774, grad_fn=<NllLossBackward0>)
# tensor(2336.0818, grad_fn=<NllLossBackward0>)
# tensor(1621.3800, grad_fn=<NllLossBackward0>)
# tensor(1834.4796, grad_fn=<NllLossBackward0>)
# tensor(1437.1310, grad_fn=<NllLossBackward0>)
# tensor(2420.4644, grad_fn=<NllLossBackward0>)
# tensor(2013.0366, grad_fn=<NllLossBackward0>)
# tensor(1370.0649, grad_fn=<NllLossBackward0>)
# tensor(1729.1327, grad_fn=<NllLossBackward0>)
# tensor(1752.5161, grad_fn=<NllLossBackward0>)
# tensor(2084.5557, grad_fn=<NllLossBackward0>)
# tensor(2125.3845, grad_fn=<NllLossBackward0>)
# tensor(2352.8931, grad_fn=<NllLossBackward0>)
# tensor(1572.3457, grad_fn=<NllLossBackward0>)
# tensor(1692.8540, grad_fn=<NllLossBackward0>)
# tensor(2599.9529, grad_fn=<NllLossBackward0>)
# tensor(1195.8187, grad_fn=<NllLossBackward0>)
# tensor(1822.4580, grad_fn=<NllLossBackward0>)
# tensor(2309.0120, grad_fn=<NllLossBackward0>)
# tensor(2118.0403, grad_fn=<NllLossBackward0>)
# tensor(2391.0969, grad_fn=<NllLossBackward0>)
# tensor(2057.5569, grad_fn=<NllLossBackward0>)
# tensor(2493.6582, grad_fn=<NllLossBackward0>)
# tensor(1977.4176, grad_fn=<NllLossBackward0>)
# tensor(1779.4330, grad_fn=<NllLossBackward0>)
# tensor(1940.4806, grad_fn=<NllLossBackward0>)
# tensor(2051.3210, grad_fn=<NllLossBackward0>)
# tensor(2443.1362, grad_fn=<NllLossBackward0>)
# tensor(1983.6406, grad_fn=<NllLossBackward0>)
# tensor(1660.7455, grad_fn=<NllLossBackward0>)
# tensor(2471.0444, grad_fn=<NllLossBackward0>)
# tensor(1971.3740, grad_fn=<NllLossBackward0>)
# tensor(2285.3503, grad_fn=<NllLossBackward0>)
# tensor(1940.0333, grad_fn=<NllLossBackward0>)
# tensor(2135.2642, grad_fn=<NllLossBackward0>)
# tensor(2947.9751, grad_fn=<NllLossBackward0>)
# tensor(2306.4614, grad_fn=<NllLossBackward0>)
# tensor(2087.8318, grad_fn=<NllLossBackward0>)
# tensor(2068.5315, grad_fn=<NllLossBackward0>)
# tensor(2181.4441, grad_fn=<NllLossBackward0>)
# tensor(1897.7886, grad_fn=<NllLossBackward0>)
# tensor(2468.6543, grad_fn=<NllLossBackward0>)
# tensor(1928.4446, grad_fn=<NllLossBackward0>)
# tensor(1844.6655, grad_fn=<NllLossBackward0>)
# tensor(2574.0608, grad_fn=<NllLossBackward0>)
# tensor(1692.4806, grad_fn=<NllLossBackward0>)
# tensor(2520.7832, grad_fn=<NllLossBackward0>)
# tensor(1589.5461, grad_fn=<NllLossBackward0>)
# tensor(2381.2925, grad_fn=<NllLossBackward0>)
# tensor(2242.6775, grad_fn=<NllLossBackward0>)
# tensor(1544.6797, grad_fn=<NllLossBackward0>)
# tensor(1811.8219, grad_fn=<NllLossBackward0>)
# tensor(1712.5570, grad_fn=<NllLossBackward0>)
# tensor(1417.5391, grad_fn=<NllLossBackward0>)
# tensor(1719.3811, grad_fn=<NllLossBackward0>)
# tensor(1881.8202, grad_fn=<NllLossBackward0>)
# tensor(1582.4375, grad_fn=<NllLossBackward0>)
# tensor(2069.0938, grad_fn=<NllLossBackward0>)
# tensor(2199.9248, grad_fn=<NllLossBackward0>)
# tensor(2407.9966, grad_fn=<NllLossBackward0>)
# tensor(2503.9529, grad_fn=<NllLossBackward0>)
# tensor(2167.3188, grad_fn=<NllLossBackward0>)
# tensor(3026.3894, grad_fn=<NllLossBackward0>)
# tensor(2858.7573, grad_fn=<NllLossBackward0>)
# tensor(1646.9487, grad_fn=<NllLossBackward0>)
# tensor(1565.0344, grad_fn=<NllLossBackward0>)
# tensor(2427.9182, grad_fn=<NllLossBackward0>)
# tensor(2630.5479, grad_fn=<NllLossBackward0>)
# tensor(2807.2153, grad_fn=<NllLossBackward0>)
# tensor(2430.4819, grad_fn=<NllLossBackward0>)
# tensor(2389.8347, grad_fn=<NllLossBackward0>)
# tensor(2816.3521, grad_fn=<NllLossBackward0>)
# tensor(2295.6260, grad_fn=<NllLossBackward0>)
# tensor(1924.4081, grad_fn=<NllLossBackward0>)
# tensor(1595.1398, grad_fn=<NllLossBackward0>)
# tensor(1973.3237, grad_fn=<NllLossBackward0>)
# tensor(1852.4486, grad_fn=<NllLossBackward0>)
# tensor(3623.7808, grad_fn=<NllLossBackward0>)
# tensor(3641.6306, grad_fn=<NllLossBackward0>)
# tensor(2114.6411, grad_fn=<NllLossBackward0>)
# tensor(1221.8372, grad_fn=<NllLossBackward0>)
# tensor(1891.8866, grad_fn=<NllLossBackward0>)
# tensor(3862.2078, grad_fn=<NllLossBackward0>)
# tensor(2616.0283, grad_fn=<NllLossBackward0>)
# tensor(2375.9321, grad_fn=<NllLossBackward0>)
# tensor(2213.8284, grad_fn=<NllLossBackward0>)
# tensor(1884.2039, grad_fn=<NllLossBackward0>)
# tensor(2287.4832, grad_fn=<NllLossBackward0>)
# tensor(2850.4141, grad_fn=<NllLossBackward0>)
# tensor(2458.2676, grad_fn=<NllLossBackward0>)
# tensor(2469.8635, grad_fn=<NllLossBackward0>)
# tensor(2282.0969, grad_fn=<NllLossBackward0>)
# tensor(2284.2822, grad_fn=<NllLossBackward0>)
# tensor(2366.5781, grad_fn=<NllLossBackward0>)
# tensor(1762.7710, grad_fn=<NllLossBackward0>)
# tensor(1433.3887, grad_fn=<NllLossBackward0>)
# tensor(2331.1587, grad_fn=<NllLossBackward0>)
# tensor(1738.6526, grad_fn=<NllLossBackward0>)
# tensor(2958.4561, grad_fn=<NllLossBackward0>)
# tensor(2427.8208, grad_fn=<NllLossBackward0>)
# tensor(2430.7158, grad_fn=<NllLossBackward0>)
# tensor(2370.8347, grad_fn=<NllLossBackward0>)
# tensor(2839.4558, grad_fn=<NllLossBackward0>)
# tensor(3394.2148, grad_fn=<NllLossBackward0>)
# tensor(2305.9248, grad_fn=<NllLossBackward0>)
# tensor(2559.1760, grad_fn=<NllLossBackward0>)
# tensor(2302.0164, grad_fn=<NllLossBackward0>)
# tensor(1682.7457, grad_fn=<NllLossBackward0>)
# tensor(2007.2262, grad_fn=<NllLossBackward0>)
# tensor(3038.1926, grad_fn=<NllLossBackward0>)
# tensor(3189.0552, grad_fn=<NllLossBackward0>)
# tensor(2955.1021, grad_fn=<NllLossBackward0>)
# tensor(2836.9236, grad_fn=<NllLossBackward0>)
# tensor(3292.7192, grad_fn=<NllLossBackward0>)
# tensor(2340.3743, grad_fn=<NllLossBackward0>)
# tensor(4297.6279, grad_fn=<NllLossBackward0>)
# tensor(3595.4746, grad_fn=<NllLossBackward0>)
# tensor(1851.9170, grad_fn=<NllLossBackward0>)
# tensor(766.4637, grad_fn=<NllLossBackward0>)
# tensor(2138.1921, grad_fn=<NllLossBackward0>)
# tensor(4048.3115, grad_fn=<NllLossBackward0>)
# tensor(3109.6560, grad_fn=<NllLossBackward0>)
# tensor(2592.1641, grad_fn=<NllLossBackward0>)
# tensor(3192.6079, grad_fn=<NllLossBackward0>)
# tensor(3012.0947, grad_fn=<NllLossBackward0>)
# tensor(3265.3796, grad_fn=<NllLossBackward0>)
# tensor(3522.5825, grad_fn=<NllLossBackward0>)
# tensor(3042.5583, grad_fn=<NllLossBackward0>)
# tensor(4552.5020, grad_fn=<NllLossBackward0>)
# tensor(4483.3511, grad_fn=<NllLossBackward0>)
# tensor(3829.2454, grad_fn=<NllLossBackward0>)
# tensor(5292.2285, grad_fn=<NllLossBackward0>)
# tensor(3562.4814, grad_fn=<NllLossBackward0>)
# tensor(2062.0640, grad_fn=<NllLossBackward0>)
# tensor(2173.1960, grad_fn=<NllLossBackward0>)
# tensor(2544.2104, grad_fn=<NllLossBackward0>)
# tensor(3370.5627, grad_fn=<NllLossBackward0>)
# tensor(2740.9314, grad_fn=<NllLossBackward0>)
# tensor(3619.7996, grad_fn=<NllLossBackward0>)
# tensor(3648.0378, grad_fn=<NllLossBackward0>)
# tensor(2610.5410, grad_fn=<NllLossBackward0>)
# tensor(2147.5857, grad_fn=<NllLossBackward0>)
# tensor(1962.2535, grad_fn=<NllLossBackward0>)
# tensor(2936.4221, grad_fn=<NllLossBackward0>)
# tensor(2555.1680, grad_fn=<NllLossBackward0>)
# tensor(882.2618, grad_fn=<NllLossBackward0>)
# tensor(2770.0767, grad_fn=<NllLossBackward0>)
# tensor(2854.9871, grad_fn=<NllLossBackward0>)
# tensor(2673.8105, grad_fn=<NllLossBackward0>)
# tensor(2666.3452, grad_fn=<NllLossBackward0>)
# tensor(2693.9592, grad_fn=<NllLossBackward0>)
# tensor(2316.0981, grad_fn=<NllLossBackward0>)
# tensor(2361.5762, grad_fn=<NllLossBackward0>)
# tensor(3111.9646, grad_fn=<NllLossBackward0>)
# tensor(2871.5254, grad_fn=<NllLossBackward0>)
# tensor(2444.3821, grad_fn=<NllLossBackward0>)
# tensor(1147.0515, grad_fn=<NllLossBackward0>)
# tensor(2121.9573, grad_fn=<NllLossBackward0>)
# tensor(2285.4971, grad_fn=<NllLossBackward0>)
# tensor(1484.6023, grad_fn=<NllLossBackward0>)
# tensor(1495.1682, grad_fn=<NllLossBackward0>)
# tensor(1738.7407, grad_fn=<NllLossBackward0>)
# tensor(1495.7542, grad_fn=<NllLossBackward0>)
# tensor(1865.3939, grad_fn=<NllLossBackward0>)
# tensor(1754.9634, grad_fn=<NllLossBackward0>)
# tensor(2261.8562, grad_fn=<NllLossBackward0>)
# tensor(1783.8938, grad_fn=<NllLossBackward0>)
# tensor(1513.6138, grad_fn=<NllLossBackward0>)
# tensor(1457.1426, grad_fn=<NllLossBackward0>)
# tensor(1965.7581, grad_fn=<NllLossBackward0>)
# tensor(1386.0527, grad_fn=<NllLossBackward0>)
# tensor(1743.9481, grad_fn=<NllLossBackward0>)
# tensor(1443.8472, grad_fn=<NllLossBackward0>)
# tensor(1520.8527, grad_fn=<NllLossBackward0>)
# tensor(1478.7328, grad_fn=<NllLossBackward0>)
# tensor(1788.3967, grad_fn=<NllLossBackward0>)
# tensor(1462.5940, grad_fn=<NllLossBackward0>)
# tensor(1474.5402, grad_fn=<NllLossBackward0>)
# tensor(1965.2764, grad_fn=<NllLossBackward0>)
# tensor(1504.3704, grad_fn=<NllLossBackward0>)
# tensor(2678.3176, grad_fn=<NllLossBackward0>)
# tensor(2351.4736, grad_fn=<NllLossBackward0>)
# tensor(2881.6997, grad_fn=<NllLossBackward0>)
# tensor(2419.9517, grad_fn=<NllLossBackward0>)
# tensor(1453.6807, grad_fn=<NllLossBackward0>)
# tensor(1754.2456, grad_fn=<NllLossBackward0>)
# tensor(1882.3618, grad_fn=<NllLossBackward0>)
# tensor(1778.8010, grad_fn=<NllLossBackward0>)
# tensor(2142.5266, grad_fn=<NllLossBackward0>)
# tensor(2123.1550, grad_fn=<NllLossBackward0>)
# tensor(2243.2166, grad_fn=<NllLossBackward0>)
# tensor(1261.7170, grad_fn=<NllLossBackward0>)
# tensor(2871.6042, grad_fn=<NllLossBackward0>)
# tensor(2256.8625, grad_fn=<NllLossBackward0>)
# tensor(1979.2681, grad_fn=<NllLossBackward0>)
# tensor(2275.5168, grad_fn=<NllLossBackward0>)
# tensor(2576.4021, grad_fn=<NllLossBackward0>)
# tensor(3472.7002, grad_fn=<NllLossBackward0>)
# tensor(2235.9854, grad_fn=<NllLossBackward0>)
# tensor(2473.2588, grad_fn=<NllLossBackward0>)
# tensor(2438.9363, grad_fn=<NllLossBackward0>)
# tensor(3228.6206, grad_fn=<NllLossBackward0>)
# tensor(2117.3501, grad_fn=<NllLossBackward0>)
# tensor(2154.3499, grad_fn=<NllLossBackward0>)
# tensor(2509.9810, grad_fn=<NllLossBackward0>)
# tensor(2720.9614, grad_fn=<NllLossBackward0>)
# tensor(3243.7522, grad_fn=<NllLossBackward0>)
# tensor(1808.5377, grad_fn=<NllLossBackward0>)
# tensor(2652.8025, grad_fn=<NllLossBackward0>)
# tensor(2017.0730, grad_fn=<NllLossBackward0>)
# tensor(3291.6040, grad_fn=<NllLossBackward0>)
# tensor(1364.5887, grad_fn=<NllLossBackward0>)
# tensor(466.8221, grad_fn=<NllLossBackward0>)
# tensor(1790.1841, grad_fn=<NllLossBackward0>)
# tensor(1354.3542, grad_fn=<NllLossBackward0>)
# tensor(969.5094, grad_fn=<NllLossBackward0>)
# tensor(2226.9470, grad_fn=<NllLossBackward0>)
# tensor(2725.5823, grad_fn=<NllLossBackward0>)
# tensor(1169.3927, grad_fn=<NllLossBackward0>)
# tensor(1421.0802, grad_fn=<NllLossBackward0>)
# tensor(1603.6395, grad_fn=<NllLossBackward0>)
# tensor(1796.2731, grad_fn=<NllLossBackward0>)
# tensor(3016.5532, grad_fn=<NllLossBackward0>)
# tensor(1393.1969, grad_fn=<NllLossBackward0>)
# tensor(947.5869, grad_fn=<NllLossBackward0>)
# tensor(1964.0924, grad_fn=<NllLossBackward0>)
# tensor(1449.1620, grad_fn=<NllLossBackward0>)
# tensor(1328.5785, grad_fn=<NllLossBackward0>)
# tensor(1280.9503, grad_fn=<NllLossBackward0>)
# tensor(1404.5861, grad_fn=<NllLossBackward0>)
# tensor(1508.2122, grad_fn=<NllLossBackward0>)
# tensor(1671.5359, grad_fn=<NllLossBackward0>)
# tensor(1845.8943, grad_fn=<NllLossBackward0>)
# tensor(2099.9844, grad_fn=<NllLossBackward0>)
# tensor(1560.7219, grad_fn=<NllLossBackward0>)
# tensor(1964.2157, grad_fn=<NllLossBackward0>)
# tensor(1308.2252, grad_fn=<NllLossBackward0>)
# tensor(3164.6824, grad_fn=<NllLossBackward0>)
# tensor(1369.9791, grad_fn=<NllLossBackward0>)
# tensor(963.8595, grad_fn=<NllLossBackward0>)
# tensor(906.8803, grad_fn=<NllLossBackward0>)
# tensor(1375.4281, grad_fn=<NllLossBackward0>)
# tensor(1697.3490, grad_fn=<NllLossBackward0>)
# tensor(2044.8638, grad_fn=<NllLossBackward0>)
# tensor(3978.7612, grad_fn=<NllLossBackward0>)
# tensor(2238.8999, grad_fn=<NllLossBackward0>)
# tensor(1515.4019, grad_fn=<NllLossBackward0>)
# tensor(2492.2639, grad_fn=<NllLossBackward0>)
# tensor(1237.3840, grad_fn=<NllLossBackward0>)
# tensor(2056.4004, grad_fn=<NllLossBackward0>)
# tensor(1139.9066, grad_fn=<NllLossBackward0>)
# tensor(1812.1509, grad_fn=<NllLossBackward0>)
# tensor(1627.2601, grad_fn=<NllLossBackward0>)
# tensor(1785.1355, grad_fn=<NllLossBackward0>)
# tensor(1581.0283, grad_fn=<NllLossBackward0>)
# tensor(2011.0300, grad_fn=<NllLossBackward0>)
# tensor(2297.9434, grad_fn=<NllLossBackward0>)
# tensor(3927.1973, grad_fn=<NllLossBackward0>)
# tensor(2000.7368, grad_fn=<NllLossBackward0>)
# tensor(2380.9458, grad_fn=<NllLossBackward0>)
# tensor(2292.6760, grad_fn=<NllLossBackward0>)
# tensor(1045.2002, grad_fn=<NllLossBackward0>)
# tensor(1473.4637, grad_fn=<NllLossBackward0>)
# tensor(1286.0803, grad_fn=<NllLossBackward0>)
# tensor(1656.4938, grad_fn=<NllLossBackward0>)
# tensor(2480.1140, grad_fn=<NllLossBackward0>)
# tensor(1984.0490, grad_fn=<NllLossBackward0>)
# tensor(1277.4921, grad_fn=<NllLossBackward0>)
# tensor(1796.5635, grad_fn=<NllLossBackward0>)
# tensor(2345.3054, grad_fn=<NllLossBackward0>)
# tensor(2006.0103, grad_fn=<NllLossBackward0>)
# tensor(2646.1338, grad_fn=<NllLossBackward0>)
# tensor(2625.4407, grad_fn=<NllLossBackward0>)
# tensor(1759.8351, grad_fn=<NllLossBackward0>)
# tensor(1508.6670, grad_fn=<NllLossBackward0>)
# tensor(1997.1432, grad_fn=<NllLossBackward0>)
# tensor(1558.9774, grad_fn=<NllLossBackward0>)
# tensor(1466.2816, grad_fn=<NllLossBackward0>)
# tensor(2254.0300, grad_fn=<NllLossBackward0>)
# tensor(2796.8916, grad_fn=<NllLossBackward0>)
# tensor(2045.0336, grad_fn=<NllLossBackward0>)
# tensor(1563.6138, grad_fn=<NllLossBackward0>)
# tensor(2734.0317, grad_fn=<NllLossBackward0>)
# tensor(2092.2361, grad_fn=<NllLossBackward0>)
# tensor(2061.7578, grad_fn=<NllLossBackward0>)
# tensor(2234.3228, grad_fn=<NllLossBackward0>)
# tensor(1968.3065, grad_fn=<NllLossBackward0>)
# tensor(1998.3298, grad_fn=<NllLossBackward0>)
# tensor(2066.5305, grad_fn=<NllLossBackward0>)
# tensor(1372.5874, grad_fn=<NllLossBackward0>)
# tensor(1148.8452, grad_fn=<NllLossBackward0>)
# tensor(2152.7844, grad_fn=<NllLossBackward0>)
# tensor(1015.9189, grad_fn=<NllLossBackward0>)
# tensor(2154.9297, grad_fn=<NllLossBackward0>)
# tensor(2313.1792, grad_fn=<NllLossBackward0>)
# tensor(1137.0886, grad_fn=<NllLossBackward0>)
# tensor(1642.4126, grad_fn=<NllLossBackward0>)
# tensor(1750.8906, grad_fn=<NllLossBackward0>)
# tensor(2457.0308, grad_fn=<NllLossBackward0>)
# tensor(2745.1448, grad_fn=<NllLossBackward0>)
# tensor(2183.0691, grad_fn=<NllLossBackward0>)
# tensor(3946.8816, grad_fn=<NllLossBackward0>)
# tensor(1454.3937, grad_fn=<NllLossBackward0>)
# tensor(2829.1396, grad_fn=<NllLossBackward0>)
# tensor(3319.4187, grad_fn=<NllLossBackward0>)
# tensor(1845.7468, grad_fn=<NllLossBackward0>)
# tensor(2921.3308, grad_fn=<NllLossBackward0>)
# tensor(1708.5032, grad_fn=<NllLossBackward0>)
# tensor(3105.8518, grad_fn=<NllLossBackward0>)
# tensor(2152.2622, grad_fn=<NllLossBackward0>)
# tensor(2115.7024, grad_fn=<NllLossBackward0>)
# tensor(2825.7522, grad_fn=<NllLossBackward0>)
# tensor(1707.9924, grad_fn=<NllLossBackward0>)
# tensor(1992.8783, grad_fn=<NllLossBackward0>)
# tensor(2807.4297, grad_fn=<NllLossBackward0>)
# tensor(2498.0750, grad_fn=<NllLossBackward0>)
# tensor(1602.9083, grad_fn=<NllLossBackward0>)
# tensor(2369.0938, grad_fn=<NllLossBackward0>)
# tensor(1688.3381, grad_fn=<NllLossBackward0>)
# tensor(2331.0986, grad_fn=<NllLossBackward0>)
# tensor(1648.6940, grad_fn=<NllLossBackward0>)
# tensor(3250.3008, grad_fn=<NllLossBackward0>)
# tensor(2472.1147, grad_fn=<NllLossBackward0>)
# tensor(2106.5867, grad_fn=<NllLossBackward0>)
# tensor(2735.7764, grad_fn=<NllLossBackward0>)
# tensor(3089.6792, grad_fn=<NllLossBackward0>)
# tensor(2409.2236, grad_fn=<NllLossBackward0>)
# tensor(3546.6614, grad_fn=<NllLossBackward0>)
# tensor(2551.8079, grad_fn=<NllLossBackward0>)
# tensor(2372.9158, grad_fn=<NllLossBackward0>)
# tensor(1595.0020, grad_fn=<NllLossBackward0>)
# tensor(4002.6577, grad_fn=<NllLossBackward0>)
# tensor(2035.1527, grad_fn=<NllLossBackward0>)
# tensor(2883.1099, grad_fn=<NllLossBackward0>)
# tensor(2289.1606, grad_fn=<NllLossBackward0>)
# tensor(1364.2640, grad_fn=<NllLossBackward0>)
# tensor(3501.9568, grad_fn=<NllLossBackward0>)
# tensor(2310.4243, grad_fn=<NllLossBackward0>)
# tensor(2658.5808, grad_fn=<NllLossBackward0>)
# tensor(1639.8019, grad_fn=<NllLossBackward0>)
# tensor(1030.0618, grad_fn=<NllLossBackward0>)
# tensor(2273.0603, grad_fn=<NllLossBackward0>)
# tensor(4526.2769, grad_fn=<NllLossBackward0>)
# tensor(3544.9382, grad_fn=<NllLossBackward0>)
# tensor(3934.6145, grad_fn=<NllLossBackward0>)
# tensor(2766.0757, grad_fn=<NllLossBackward0>)
# tensor(2829.2896, grad_fn=<NllLossBackward0>)
# tensor(3258.3718, grad_fn=<NllLossBackward0>)
# tensor(2794.5674, grad_fn=<NllLossBackward0>)
# tensor(4435.6748, grad_fn=<NllLossBackward0>)
# tensor(3390.3777, grad_fn=<NllLossBackward0>)
# tensor(2798.3081, grad_fn=<NllLossBackward0>)
# tensor(1161.7216, grad_fn=<NllLossBackward0>)
# tensor(1603.9017, grad_fn=<NllLossBackward0>)
# tensor(1908.8079, grad_fn=<NllLossBackward0>)
# tensor(2781.3665, grad_fn=<NllLossBackward0>)
# tensor(3523.9468, grad_fn=<NllLossBackward0>)
# tensor(1844.4911, grad_fn=<NllLossBackward0>)
# tensor(2436.0400, grad_fn=<NllLossBackward0>)
# tensor(3328.1499, grad_fn=<NllLossBackward0>)
# tensor(3384.5261, grad_fn=<NllLossBackward0>)
# tensor(2738.1445, grad_fn=<NllLossBackward0>)
# tensor(2389.2915, grad_fn=<NllLossBackward0>)
# tensor(1686.5754, grad_fn=<NllLossBackward0>)
# tensor(1967.1008, grad_fn=<NllLossBackward0>)
# tensor(2255.0266, grad_fn=<NllLossBackward0>)
# tensor(3654.1001, grad_fn=<NllLossBackward0>)
# tensor(3875.1606, grad_fn=<NllLossBackward0>)
# tensor(1640.3917, grad_fn=<NllLossBackward0>)
# tensor(1511.7717, grad_fn=<NllLossBackward0>)
# tensor(2297.5786, grad_fn=<NllLossBackward0>)
# tensor(1183.6075, grad_fn=<NllLossBackward0>)
# tensor(2637.7202, grad_fn=<NllLossBackward0>)
# tensor(2141.9397, grad_fn=<NllLossBackward0>)
# tensor(2798.9685, grad_fn=<NllLossBackward0>)
# tensor(2458.2283, grad_fn=<NllLossBackward0>)
# tensor(2345.4785, grad_fn=<NllLossBackward0>)
# tensor(1249.6318, grad_fn=<NllLossBackward0>)
# ...
# tensor(3288.2234, grad_fn=<NllLossBackward0>)
# tensor(3446.2236, grad_fn=<NllLossBackward0>)
# tensor(3332.8677, grad_fn=<NllLossBackward0>)
# tensor(3513.2471, grad_fn=<NllLossBackward0>)
# tensor(3469.6748, grad_fn=<NllLossBackward0>)
# tensor(2746.0110, grad_fn=<NllLossBackward0>)
# tensor(3046.2307, grad_fn=<NllLossBackward0>)
# tensor(3233.4998, grad_fn=<NllLossBackward0>)
# tensor(4058.4165, grad_fn=<NllLossBackward0>)
# tensor(3435.6372, grad_fn=<NllLossBackward0>)
# tensor(2958.3567, grad_fn=<NllLossBackward0>)
# tensor(2959.6377, grad_fn=<NllLossBackward0>)
# tensor(2956.4248, grad_fn=<NllLossBackward0>)
# tensor(2616.7473, grad_fn=<NllLossBackward0>)
# tensor(3968.4880, grad_fn=<NllLossBackward0>)
# tensor(2566.6746, grad_fn=<NllLossBackward0>)
# tensor(3552.7749, grad_fn=<NllLossBackward0>)
# tensor(3288.9294, grad_fn=<NllLossBackward0>)
# tensor(2417.8970, grad_fn=<NllLossBackward0>)
# tensor(2194.7185, grad_fn=<NllLossBackward0>)
# tensor(3086.5242, grad_fn=<NllLossBackward0>)
# tensor(2679.6865, grad_fn=<NllLossBackward0>)
# tensor(3233.1482, grad_fn=<NllLossBackward0>)
# tensor(3141.0483, grad_fn=<NllLossBackward0>)
# tensor(2398.2361, grad_fn=<NllLossBackward0>)
# tensor(2217.8096, grad_fn=<NllLossBackward0>)
# tensor(2987.8906, grad_fn=<NllLossBackward0>)
# tensor(3498.1660, grad_fn=<NllLossBackward0>)
# tensor(4633.1929, grad_fn=<NllLossBackward0>)
# tensor(2311.8057, grad_fn=<NllLossBackward0>)
# tensor(5095.4214, grad_fn=<NllLossBackward0>)
# tensor(3096.1262, grad_fn=<NllLossBackward0>)
# tensor(1964.0193, grad_fn=<NllLossBackward0>)
# tensor(2244.5486, grad_fn=<NllLossBackward0>)
# tensor(4224.8857, grad_fn=<NllLossBackward0>)
# tensor(2638.5090, grad_fn=<NllLossBackward0>)
# tensor(3647.7332, grad_fn=<NllLossBackward0>)
# tensor(2404.4744, grad_fn=<NllLossBackward0>)
# tensor(2636.0190, grad_fn=<NllLossBackward0>)
# tensor(1743.7732, grad_fn=<NllLossBackward0>)
# tensor(2578.9761, grad_fn=<NllLossBackward0>)
# tensor(1624.2825, grad_fn=<NllLossBackward0>)
# tensor(2726.5576, grad_fn=<NllLossBackward0>)
# tensor(2532.4778, grad_fn=<NllLossBackward0>)
# tensor(2470.2092, grad_fn=<NllLossBackward0>)
# tensor(2773.3584, grad_fn=<NllLossBackward0>)
# tensor(2610.6851, grad_fn=<NllLossBackward0>)
# tensor(3012.7932, grad_fn=<NllLossBackward0>)
# tensor(2931.5063, grad_fn=<NllLossBackward0>)
# tensor(2979.6787, grad_fn=<NllLossBackward0>)
# tensor(2741.6033, grad_fn=<NllLossBackward0>)
# tensor(2512.9414, grad_fn=<NllLossBackward0>)
# tensor(2470.2537, grad_fn=<NllLossBackward0>)
# tensor(2244.5293, grad_fn=<NllLossBackward0>)
# tensor(2774.4048, grad_fn=<NllLossBackward0>)
# tensor(1958.4025, grad_fn=<NllLossBackward0>)
# tensor(3033.5061, grad_fn=<NllLossBackward0>)
# tensor(4331.0669, grad_fn=<NllLossBackward0>)
# tensor(3076.4758, grad_fn=<NllLossBackward0>)
# tensor(2348.4004, grad_fn=<NllLossBackward0>)
# tensor(2694.1587, grad_fn=<NllLossBackward0>)
# tensor(2367.5610, grad_fn=<NllLossBackward0>)
# tensor(3057.4155, grad_fn=<NllLossBackward0>)
# tensor(2405.9883, grad_fn=<NllLossBackward0>)
# tensor(4104.9277, grad_fn=<NllLossBackward0>)
# tensor(2808.3040, grad_fn=<NllLossBackward0>)
# tensor(1374.6505, grad_fn=<NllLossBackward0>)
# tensor(3233.4392, grad_fn=<NllLossBackward0>)
# tensor(2138.4204, grad_fn=<NllLossBackward0>)
# tensor(1946.6425, grad_fn=<NllLossBackward0>)
# tensor(3289.5344, grad_fn=<NllLossBackward0>)
# tensor(2657.8149, grad_fn=<NllLossBackward0>)
# tensor(3495.7085, grad_fn=<NllLossBackward0>)
# tensor(4692., grad_fn=<NllLossBackward0>)
# tensor(3764.9795, grad_fn=<NllLossBackward0>)
# tensor(2627.8960, grad_fn=<NllLossBackward0>)
# tensor(3234.4878, grad_fn=<NllLossBackward0>)
# tensor(2553.4441, grad_fn=<NllLossBackward0>)
# tensor(2951.2900, grad_fn=<NllLossBackward0>)
# tensor(3243.3452, grad_fn=<NllLossBackward0>)
# tensor(3022.6958, grad_fn=<NllLossBackward0>)
# tensor(3159.9775, grad_fn=<NllLossBackward0>)
# tensor(2984.3269, grad_fn=<NllLossBackward0>)
# tensor(3308.6863, grad_fn=<NllLossBackward0>)
# tensor(3980.1338, grad_fn=<NllLossBackward0>)
# tensor(2907.0244, grad_fn=<NllLossBackward0>)
# tensor(2619.8076, grad_fn=<NllLossBackward0>)
# tensor(2889.5259, grad_fn=<NllLossBackward0>)
# tensor(3284.5901, grad_fn=<NllLossBackward0>)
# tensor(3645.0830, grad_fn=<NllLossBackward0>)
# tensor(3462.1882, grad_fn=<NllLossBackward0>)
# tensor(3501.2441, grad_fn=<NllLossBackward0>)
# tensor(2775.2654, grad_fn=<NllLossBackward0>)
# tensor(4322.6562, grad_fn=<NllLossBackward0>)
# tensor(3113.5642, grad_fn=<NllLossBackward0>)
# tensor(4065.0444, grad_fn=<NllLossBackward0>)
# tensor(3959.0337, grad_fn=<NllLossBackward0>)
# tensor(3794.9370, grad_fn=<NllLossBackward0>)
# tensor(4360.0610, grad_fn=<NllLossBackward0>)
# tensor(2686.3022, grad_fn=<NllLossBackward0>)
# tensor(3131.1687, grad_fn=<NllLossBackward0>)
# tensor(4240.5684, grad_fn=<NllLossBackward0>)
# tensor(3289.6516, grad_fn=<NllLossBackward0>)
# tensor(3927.9165, grad_fn=<NllLossBackward0>)
# tensor(2314.0935, grad_fn=<NllLossBackward0>)
# tensor(2077.5698, grad_fn=<NllLossBackward0>)
# tensor(3337.7664, grad_fn=<NllLossBackward0>)
# tensor(2685.2134, grad_fn=<NllLossBackward0>)
# tensor(2054.9204, grad_fn=<NllLossBackward0>)
# tensor(2534.5540, grad_fn=<NllLossBackward0>)
# tensor(3570.0137, grad_fn=<NllLossBackward0>)
# tensor(2217.4351, grad_fn=<NllLossBackward0>)
# tensor(2313.8149, grad_fn=<NllLossBackward0>)
# tensor(2509.4995, grad_fn=<NllLossBackward0>)
# tensor(3177.4719, grad_fn=<NllLossBackward0>)
# tensor(3163.2126, grad_fn=<NllLossBackward0>)
# tensor(2079.5691, grad_fn=<NllLossBackward0>)
# tensor(2323.6877, grad_fn=<NllLossBackward0>)
# tensor(2916.0901, grad_fn=<NllLossBackward0>)
# tensor(1811.7013, grad_fn=<NllLossBackward0>)
# tensor(2972.7366, grad_fn=<NllLossBackward0>)
# tensor(1710.7139, grad_fn=<NllLossBackward0>)
# tensor(2378.7051, grad_fn=<NllLossBackward0>)
# tensor(1983.5441, grad_fn=<NllLossBackward0>)
# tensor(2297.6169, grad_fn=<NllLossBackward0>)
# tensor(2948.1367, grad_fn=<NllLossBackward0>)
# tensor(3533.7070, grad_fn=<NllLossBackward0>)
# tensor(3577.0757, grad_fn=<NllLossBackward0>)
# tensor(2703.9756, grad_fn=<NllLossBackward0>)
# tensor(3586.3818, grad_fn=<NllLossBackward0>)
# tensor(2703.1399, grad_fn=<NllLossBackward0>)
# tensor(2644.6487, grad_fn=<NllLossBackward0>)
# tensor(3842.2336, grad_fn=<NllLossBackward0>)
# tensor(2779.3809, grad_fn=<NllLossBackward0>)
# tensor(2692.3223, grad_fn=<NllLossBackward0>)
# tensor(3752.0940, grad_fn=<NllLossBackward0>)
# tensor(2731.8921, grad_fn=<NllLossBackward0>)
# tensor(3600.2996, grad_fn=<NllLossBackward0>)
# tensor(2501.3975, grad_fn=<NllLossBackward0>)
# tensor(2341.9214, grad_fn=<NllLossBackward0>)
# tensor(3737.9219, grad_fn=<NllLossBackward0>)
# tensor(2464.6025, grad_fn=<NllLossBackward0>)
# tensor(3106.9355, grad_fn=<NllLossBackward0>)
# tensor(3616.4900, grad_fn=<NllLossBackward0>)
# tensor(3531.9744, grad_fn=<NllLossBackward0>)
# tensor(3248.6289, grad_fn=<NllLossBackward0>)
# tensor(4767.4961, grad_fn=<NllLossBackward0>)
# tensor(5106.3496, grad_fn=<NllLossBackward0>)
# tensor(1434.5471, grad_fn=<NllLossBackward0>)
# tensor(2330.7852, grad_fn=<NllLossBackward0>)
# tensor(1866.5552, grad_fn=<NllLossBackward0>)
# tensor(3643.6611, grad_fn=<NllLossBackward0>)
# tensor(2736.4456, grad_fn=<NllLossBackward0>)
# tensor(4621.8691, grad_fn=<NllLossBackward0>)
# tensor(5070.7021, grad_fn=<NllLossBackward0>)
# tensor(2767.4133, grad_fn=<NllLossBackward0>)
# tensor(3599.6123, grad_fn=<NllLossBackward0>)
# tensor(3157.0598, grad_fn=<NllLossBackward0>)
# tensor(4625.9595, grad_fn=<NllLossBackward0>)
# tensor(2008.2812, grad_fn=<NllLossBackward0>)
# tensor(3335.1963, grad_fn=<NllLossBackward0>)
# tensor(2973.5229, grad_fn=<NllLossBackward0>)
# tensor(3369.7856, grad_fn=<NllLossBackward0>)
# tensor(2883.6326, grad_fn=<NllLossBackward0>)
# tensor(4422.6436, grad_fn=<NllLossBackward0>)
# tensor(3405.5210, grad_fn=<NllLossBackward0>)
# tensor(3124.9521, grad_fn=<NllLossBackward0>)
# tensor(5875.2783, grad_fn=<NllLossBackward0>)
# tensor(3335.5059, grad_fn=<NllLossBackward0>)
# tensor(2722.9353, grad_fn=<NllLossBackward0>)
# tensor(3152.5496, grad_fn=<NllLossBackward0>)
# tensor(1862.8417, grad_fn=<NllLossBackward0>)
# tensor(3780.6230, grad_fn=<NllLossBackward0>)
# tensor(3630.0437, grad_fn=<NllLossBackward0>)
# tensor(2533.5447, grad_fn=<NllLossBackward0>)
# tensor(2075.9727, grad_fn=<NllLossBackward0>)
# tensor(2541.6538, grad_fn=<NllLossBackward0>)
# tensor(3153.5154, grad_fn=<NllLossBackward0>)
# tensor(2754.3459, grad_fn=<NllLossBackward0>)
# tensor(2051.8926, grad_fn=<NllLossBackward0>)
# tensor(2301.3215, grad_fn=<NllLossBackward0>)
# tensor(3271.6575, grad_fn=<NllLossBackward0>)
# tensor(2121.6143, grad_fn=<NllLossBackward0>)
# tensor(2638.9138, grad_fn=<NllLossBackward0>)
# tensor(2858.4189, grad_fn=<NllLossBackward0>)
# tensor(2578.7151, grad_fn=<NllLossBackward0>)
# tensor(2088.2825, grad_fn=<NllLossBackward0>)
# tensor(2883.0354, grad_fn=<NllLossBackward0>)
# tensor(2116.0156, grad_fn=<NllLossBackward0>)
# tensor(1744.2894, grad_fn=<NllLossBackward0>)
# tensor(2948.0181, grad_fn=<NllLossBackward0>)
# tensor(2294.2922, grad_fn=<NllLossBackward0>)
# tensor(2709.6638, grad_fn=<NllLossBackward0>)
# tensor(2747.4604, grad_fn=<NllLossBackward0>)
# tensor(1730.5034, grad_fn=<NllLossBackward0>)
# tensor(2986.0830, grad_fn=<NllLossBackward0>)
# tensor(2283.5825, grad_fn=<NllLossBackward0>)
# tensor(2986.2122, grad_fn=<NllLossBackward0>)
# tensor(2872.7273, grad_fn=<NllLossBackward0>)
# tensor(3373.1985, grad_fn=<NllLossBackward0>)
# tensor(2791.1455, grad_fn=<NllLossBackward0>)
# tensor(1943.3521, grad_fn=<NllLossBackward0>)
# tensor(3935.8379, grad_fn=<NllLossBackward0>)
# tensor(2990.1885, grad_fn=<NllLossBackward0>)
# tensor(3643.4856, grad_fn=<NllLossBackward0>)
# tensor(2305.2344, grad_fn=<NllLossBackward0>)
# tensor(2167.6230, grad_fn=<NllLossBackward0>)
# tensor(2554.6138, grad_fn=<NllLossBackward0>)
# tensor(2092.0576, grad_fn=<NllLossBackward0>)
# tensor(1927.7095, grad_fn=<NllLossBackward0>)
# tensor(2999.0188, grad_fn=<NllLossBackward0>)
# tensor(2748.9385, grad_fn=<NllLossBackward0>)
# tensor(3435.0457, grad_fn=<NllLossBackward0>)
# tensor(4093.3586, grad_fn=<NllLossBackward0>)
# tensor(3369.8525, grad_fn=<NllLossBackward0>)
# tensor(3518.8835, grad_fn=<NllLossBackward0>)
# tensor(2329.7815, grad_fn=<NllLossBackward0>)
# tensor(2585.8579, grad_fn=<NllLossBackward0>)
# tensor(2050.8770, grad_fn=<NllLossBackward0>)
# tensor(2978.5024, grad_fn=<NllLossBackward0>)
# tensor(3494.1909, grad_fn=<NllLossBackward0>)
# tensor(2360.2136, grad_fn=<NllLossBackward0>)
# tensor(2327.9861, grad_fn=<NllLossBackward0>)
# tensor(2920.3853, grad_fn=<NllLossBackward0>)
# tensor(2491.7461, grad_fn=<NllLossBackward0>)
# tensor(3051.0383, grad_fn=<NllLossBackward0>)
# tensor(2755.3630, grad_fn=<NllLossBackward0>)
# tensor(3046.2451, grad_fn=<NllLossBackward0>)
# tensor(6555.6802, grad_fn=<NllLossBackward0>)
# tensor(2770.9927, grad_fn=<NllLossBackward0>)
# tensor(2426.3689, grad_fn=<NllLossBackward0>)
# tensor(4146.7622, grad_fn=<NllLossBackward0>)
# tensor(2574.9316, grad_fn=<NllLossBackward0>)
# tensor(4043.6392, grad_fn=<NllLossBackward0>)
# tensor(3271.1455, grad_fn=<NllLossBackward0>)
# tensor(2831.3557, grad_fn=<NllLossBackward0>)
# tensor(2606.8787, grad_fn=<NllLossBackward0>)
# tensor(3898.0305, grad_fn=<NllLossBackward0>)
# tensor(3026.5601, grad_fn=<NllLossBackward0>)
# tensor(1983.4756, grad_fn=<NllLossBackward0>)
# tensor(3182.3689, grad_fn=<NllLossBackward0>)
# tensor(2437.8755, grad_fn=<NllLossBackward0>)
# tensor(3425.9067, grad_fn=<NllLossBackward0>)
# tensor(3577.2246, grad_fn=<NllLossBackward0>)
# tensor(3445.5586, grad_fn=<NllLossBackward0>)
# tensor(2701.3154, grad_fn=<NllLossBackward0>)
# tensor(3319.5786, grad_fn=<NllLossBackward0>)
# tensor(3496.5432, grad_fn=<NllLossBackward0>)
# tensor(2840.1338, grad_fn=<NllLossBackward0>)
# tensor(2919.9033, grad_fn=<NllLossBackward0>)
# tensor(3418.5964, grad_fn=<NllLossBackward0>)
# tensor(3311.0481, grad_fn=<NllLossBackward0>)
# tensor(3615.2686, grad_fn=<NllLossBackward0>)
# tensor(2697.2319, grad_fn=<NllLossBackward0>)
# tensor(3923.2214, grad_fn=<NllLossBackward0>)
# tensor(2897.3325, grad_fn=<NllLossBackward0>)
# tensor(2888.6157, grad_fn=<NllLossBackward0>)
# tensor(3151.0059, grad_fn=<NllLossBackward0>)
# tensor(3968.4829, grad_fn=<NllLossBackward0>)
# tensor(3837.3630, grad_fn=<NllLossBackward0>)
# tensor(2624.3438, grad_fn=<NllLossBackward0>)
# tensor(2724.7185, grad_fn=<NllLossBackward0>)
# tensor(2466.2717, grad_fn=<NllLossBackward0>)
# tensor(3696.4231, grad_fn=<NllLossBackward0>)
# tensor(4293.2925, grad_fn=<NllLossBackward0>)
# tensor(2841.8452, grad_fn=<NllLossBackward0>)
# tensor(3147.1746, grad_fn=<NllLossBackward0>)
# tensor(5088.0229, grad_fn=<NllLossBackward0>)
# tensor(3652.3833, grad_fn=<NllLossBackward0>)
# tensor(2865.6785, grad_fn=<NllLossBackward0>)
# tensor(2822.1345, grad_fn=<NllLossBackward0>)
# tensor(3223.3997, grad_fn=<NllLossBackward0>)
# tensor(2846.5198, grad_fn=<NllLossBackward0>)
# tensor(3752.5544, grad_fn=<NllLossBackward0>)
# tensor(2927.2117, grad_fn=<NllLossBackward0>)
# tensor(3012.5894, grad_fn=<NllLossBackward0>)
# tensor(3866.8164, grad_fn=<NllLossBackward0>)
# tensor(2719.1257, grad_fn=<NllLossBackward0>)
# tensor(3992.5703, grad_fn=<NllLossBackward0>)
# tensor(2868.9021, grad_fn=<NllLossBackward0>)
# tensor(3516.8130, grad_fn=<NllLossBackward0>)
# tensor(3366.5691, grad_fn=<NllLossBackward0>)
# tensor(2541.0059, grad_fn=<NllLossBackward0>)
# tensor(2409.9836, grad_fn=<NllLossBackward0>)
# tensor(2632.2209, grad_fn=<NllLossBackward0>)
# tensor(2875.8225, grad_fn=<NllLossBackward0>)
# tensor(3052.5886, grad_fn=<NllLossBackward0>)
# tensor(3484.8428, grad_fn=<NllLossBackward0>)
# tensor(2740.8286, grad_fn=<NllLossBackward0>)
# tensor(2875.6177, grad_fn=<NllLossBackward0>)
# tensor(3030.4099, grad_fn=<NllLossBackward0>)
# tensor(4091.5293, grad_fn=<NllLossBackward0>)
# tensor(3916.9639, grad_fn=<NllLossBackward0>)
# tensor(4432.0361, grad_fn=<NllLossBackward0>)
# tensor(5076.5557, grad_fn=<NllLossBackward0>)
# tensor(4398.3677, grad_fn=<NllLossBackward0>)
# tensor(2961.5410, grad_fn=<NllLossBackward0>)
# tensor(2645.7996, grad_fn=<NllLossBackward0>)
# tensor(3704.6062, grad_fn=<NllLossBackward0>)
# tensor(3741.9158, grad_fn=<NllLossBackward0>)
# tensor(4502.6797, grad_fn=<NllLossBackward0>)
# tensor(3248.3599, grad_fn=<NllLossBackward0>)
# tensor(3679.3848, grad_fn=<NllLossBackward0>)
# tensor(4507.8081, grad_fn=<NllLossBackward0>)
# tensor(3437.9910, grad_fn=<NllLossBackward0>)
# tensor(3110.9062, grad_fn=<NllLossBackward0>)
# tensor(2347.4312, grad_fn=<NllLossBackward0>)
# tensor(2886.0869, grad_fn=<NllLossBackward0>)
# tensor(2700.4612, grad_fn=<NllLossBackward0>)
# tensor(5732.8120, grad_fn=<NllLossBackward0>)
# tensor(6082.7969, grad_fn=<NllLossBackward0>)
# tensor(3633.5769, grad_fn=<NllLossBackward0>)
# tensor(2255.7793, grad_fn=<NllLossBackward0>)
# tensor(2992.5596, grad_fn=<NllLossBackward0>)
# tensor(5164.2104, grad_fn=<NllLossBackward0>)
# tensor(4527.6089, grad_fn=<NllLossBackward0>)
# tensor(3708.9790, grad_fn=<NllLossBackward0>)
# tensor(3062.1899, grad_fn=<NllLossBackward0>)
# tensor(3082.7930, grad_fn=<NllLossBackward0>)
# tensor(3736.9473, grad_fn=<NllLossBackward0>)
# tensor(4554.1968, grad_fn=<NllLossBackward0>)
# tensor(3060.6160, grad_fn=<NllLossBackward0>)
# tensor(3532.5413, grad_fn=<NllLossBackward0>)
# tensor(4294.5684, grad_fn=<NllLossBackward0>)
# tensor(2172.2170, grad_fn=<NllLossBackward0>)
# tensor(3885.6589, grad_fn=<NllLossBackward0>)
# tensor(2688.2512, grad_fn=<NllLossBackward0>)
# tensor(2299.8594, grad_fn=<NllLossBackward0>)
# tensor(3458.3450, grad_fn=<NllLossBackward0>)
# tensor(2943.0198, grad_fn=<NllLossBackward0>)
# tensor(3601.1372, grad_fn=<NllLossBackward0>)
# tensor(4112.9727, grad_fn=<NllLossBackward0>)
# tensor(3314.2388, grad_fn=<NllLossBackward0>)
# tensor(4143.4907, grad_fn=<NllLossBackward0>)
# tensor(4159.5635, grad_fn=<NllLossBackward0>)
# tensor(4897.9541, grad_fn=<NllLossBackward0>)
# tensor(3443.6462, grad_fn=<NllLossBackward0>)
# tensor(3883.0881, grad_fn=<NllLossBackward0>)
# tensor(2523.6443, grad_fn=<NllLossBackward0>)
# tensor(2953.8625, grad_fn=<NllLossBackward0>)
# tensor(3204.4131, grad_fn=<NllLossBackward0>)
# tensor(4635.3950, grad_fn=<NllLossBackward0>)
# tensor(5437.1753, grad_fn=<NllLossBackward0>)
# tensor(4785.4009, grad_fn=<NllLossBackward0>)
# TaggerModel(
#   (word_embedding): Embedding(19671, 100)
#   (rnn): RNN(100, 50, batch_first=True)
#   (hidden_to_tag): Linear(in_features=50, out_features=18, bias=True)
# )

# %% [markdown]
# * b) Now evaluate the tagger on the dev data (`pos-data/en_ewt-dev.conll`) with accuracy (make sure to not count the padding tokens).

# %% [markdown]
# ## 3. Implement a Bi-RNN in Pytorch
# In this assignment we are going to implement a bidirectional RNN classifier in Pytorch including dropout layers, and train it for the task of topic classification.
#
# You can use the following function for data reading:

# %%
def load_topics(path):
    text = []
    labels = []
    for lineIdx, line in enumerate(open(path)):
        tok = line.strip().split('\t')
        labels.append(tok[0])
        text.append(tok[1].split(' '))
    return text, labels

topic_train_text, topic_train_labels = load_topics('topic-data/train.txt')
topic_dev_text, topic_dev_labels = load_topics('topic-data/dev.txt')

# %% [markdown]
# * a) Convert the data to a format that can be used in a Pytorch module. In this assignment, we can cap the size of an utterance, as each utterance only needs 1 label. Use a maximum length of 64 words, for longer sentences, only keep the first 64 words. A special `<PAD>` token can be used for padding for sentences shorter as 64 words. For the unknown words in the test set, you can use the `<PAD>` token as well.
#
# **hint**: the shape of the training data should be 13,000 by 64

# %%
import torch


# Your implementation goes here:

# %% [markdown]
# * b) Convert your input into batches of size 32, similar as you did in assignment 1b

# %% [markdown]
# * c) Implement a classification model in Pytorch using a [`torch.nn.Embedding`](https://pytorch.org/docs/stable/generated/torch.nn.Embedding.html) layer and a [`torch.nn.RNN`](https://pytorch.org/docs/stable/generated/torch.nn.RNN.html) layer. Train this classification model on the language identification data, and evaluate its performance. Note that during each training step, you now get the predictions and loss on a whole batch directly. Use the following hyperparameters: 5 epochs over the full training data, word embeddings dimension: 100, rnn dimension of 50, learning rate of 0.01 in an [Adam optimizer](https://pytorch.org/docs/stable/optim.html) and a [CrossEntropyLoss](https://pytorch.org/docs/stable/generated/torch.nn.CrossEntropyLoss.html).
#
# Hints:
# * see also the hints for assignment2a
# * Set bidirectional=True for the RNN layer (so that we are training a RNN), note that the input dimensions of the next layer should then be rnn_dim*2.
# * We use words as inputs, and need only one label per sentence, so you should use the output of the last item from the forward layer, and the output of the first item for the backward layer.

# %%
# Hint: In torch, the BiRNN returns a concatenation of the forward and 
# backward layer. Here is an example of how these can be extracted again
#     backward_out = rnn_out[:,0,-size:].squeeze()
#     forward_out = rnn_out[:,-1,:size].squeeze()

# %% [markdown]
# * d) Add a `torch.nn.Dropout` layer with a masking probability of 0.2 between the word embeddings and the RNN layer and
#   another dropout layer with a masking probability of 0.3 between the rnn layer and the output layer. Evaluate the
#   performance again, is the performance higher?, why would this be the case?
